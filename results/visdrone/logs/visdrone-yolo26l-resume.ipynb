# %% [markdown]
# # VisDrone — yolo26**l**
#
# Lam tron mot size: baseline -> prune 50% -> finetune + CWD -> val.
# Ket qua la **hai dong** cua bang: `YOLO26-L` va `Ours-L`.
#
# | | |
# |---|---|
# | Baseline | `yolo26l.pt` (COCO), 100 epoch tren VisDrone |
# | Ours | L1-norm uniform 50% (div 8) + 100 epoch CWD tau=9, kd_layers=neck |
# | Batch / imgsz / seed | 16 / 640 / 0 |
# | cos_lr / patience / warmup | False / 100 / 3.0 |
# | Uoc tinh | ~17h, **2-3 phien** |
#
# > Bon notebook n/s/m/l dung **y het** cac tham so nay. Doi mot cai thoi la ca
# > bang het so sanh duoc.
#
# ## Cach chay
#
# 1. Settings -> Accelerator **GPU T4 x2**, **Internet: On**
# 2. **Save & Run All**. Lan dau khong can Add Data.
# 3. Phien tu dung o 10h. Cell cuoi bao con thieu bao nhieu epoch -> Add Data
#    output cua chinh lan chay nay roi Save & Run All lai.
# 4. Xong thi gui lai bang 2 dong o cell cuoi.
#
# Logic nam trong `notebooks/share_visdrone/vd_common.py` trong repo, cell setup
# tu `git pull` moi lan chay — sua loi o do la ca nhom co ngay, khong phai import
# lai notebook.
#
# Repo: https://github.com/xauskeleton/yolo26_prune_cwd

# %% [markdown]
# ## 1. Setup

# %%
import os, sys, pathlib, subprocess

REPO_DIR = pathlib.Path("/kaggle/working/yolo")
# Luon keo ban moi nhat: logic nam trong repo nen sua o do la ca nhom co ngay.
if REPO_DIR.exists():
    subprocess.run(["git", "-C", str(REPO_DIR), "pull", "--ff-only"], check=False)
else:
    subprocess.run(["git", "clone", "--depth", "1",
                    "https://github.com/xauskeleton/yolo26_prune_cwd", str(REPO_DIR)], check=True)
os.chdir(REPO_DIR)

# Phai dung fork nay, KHONG "pip install ultralytics": checkpoint sau khi prune
# duoc pickle voi ultralytics.nn.tasks_pruned nen ban chinh thuc khong load duoc.
for d in (REPO_DIR, REPO_DIR / "pruning", REPO_DIR / "notebooks" / "share_visdrone"):
    sys.path.insert(0, str(d))
# DDP sinh tien trinh con chay file tam ngoai repo -> phai truyen qua PYTHONPATH.
os.environ["PYTHONPATH"] = str(REPO_DIR)

subprocess.run([sys.executable, "-m", "pip", "install", "-q",
                "-r", "requirements.txt"], check=False)
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-e", ".",
                "--no-deps"], check=False)

import torch
import vd_common as V
print("GPU:", torch.cuda.device_count(), "| vd_common:", V.__file__)
# Out:
# Cloning into '/kaggle/working/yolo'...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.6/766.6 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 64.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 62.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 28.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 33.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 82.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 85.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.10.0+cu128 requires torch==2.10.0, but you have torch 2.6.0 which is incompatible.
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# GPU: 2 | vd_common: /kaggle/working/yolo/notebooks/share_visdrone/vd_common.py

# %% [markdown]
# ## 2. Cau hinh

# %%
SIZE   = "l"
MODEL  = "yolo26l.pt"
RATIO  = 0.5

BASE_NAME = "vd_yolo26l"
OURS_NAME = "vd_oursl"
PRUNED = REPO_DIR / "weights" / "yolo26l_vd_pruned50.pt"

V.init(
    REPO_DIR = REPO_DIR,
    DATA     = "VisDrone.yaml",   # Ultralytics tu tai 2.3 GB, can Internet: On
    EPOCHS   = 100,
    BATCH    = 16,
    IMGSZ    = 640,
    DEVICE   = "0,1" if torch.cuda.device_count() > 1 else "0",
    # Chot cung thay vi de mac dinh: cac run VOC truoc day khong dong nhat
    # (n/s/l dung batch 32 + cos_lr=True + patience 20-30, m dung 16/False/100).
    COS_LR   = False,
    PATIENCE = 100,
    WARMUP   = 3.0,
    # Kaggle giet phien o 12h va phien bi giet thi KHONG luu output.
    STOP_AFTER_H = 10.0,
)

# Chi dung khi chi co moi mot file last.pt roi le (phien bi danh dau failed).
# Upload ca thu muc <run_name>/weights/ thi khong can dien gi.
MANUAL_LAST = {BASE_NAME: "", OURS_NAME: ""}

print(BASE_NAME, "|", OURS_NAME, "|", V.CFG["DEVICE"])
# Out:
# vd_yolo26l | vd_oursl | 0,1

# %% [markdown]
# ## 3. Resume

# %%
V.restore(BASE_NAME, OURS_NAME, PRUNED, MANUAL_LAST)
# Out:
#   vd_yolo26l: 100 epoch  <- /kaggle/input/datasets/chimbellll/resume/vd_resume_l/vd_yolo26l
#   vd_oursl: 42 epoch  <- /kaggle/input/datasets/chimbellll/resume/vd_resume_l/vd_oursl
#
# baseline : 100 / 100 epoch
# ours     : 42 / 100 epoch

# %% [markdown]
# ## 4. Baseline yolo26l

# %%
n_base = V.train(BASE_NAME, MODEL)

if n_base < 100:
    print()
    print("Baseline moi {}/100 epoch - het gio phien nay.".format(n_base))
    print("Add Data output lan nay roi Save & Run All lai. Cac cell duoi bo qua.")
# Out:
# [vd_yolo26l] da du 100/100 epoch, bo qua

# %% [markdown]
# ## 5. Prune 50%

# %%
BEST_BASE = REPO_DIR / "runs" / BASE_NAME / "weights" / "best.pt"

if n_base < 100:
    print("Bo qua: baseline chua xong.")
else:
    V.prune50(SIZE, BEST_BASE, PRUNED, RATIO)
# Out:
# Step 1: Thu thập BatchNorm layers...
#   Tổng BN layers: 178
#   Ignore (residual): 60
#   Chunk constraint: 0
#   Prunable BN layers: 118
#
# Step 6: Tạo pruned model config...
#   nc: 10, scale: l
#   Backbone layers: 11
#   Head layers: 13
#     [ 0] n=1 Conv                 args=[64, 3, 2]
#     [ 1] n=1 Conv                 args=[128, 3, 2]
#     [ 2] n=2 C3k2Pruned           args=[256, True]
#     [ 3] n=1 Conv                 args=[256, 3, 2]
#     [ 4] n=2 C3k2Pruned           args=[512, True]
#     [ 5] n=1 Conv                 args=[512, 3, 2]
#     [ 6] n=2 C3k2Pruned           args=[512, True]
#     [ 7] n=1 Conv                 args=[1024, 3, 2]
#     [ 8] n=2 C3k2Pruned           args=[1024, True]
#     [ 9] n=1 SPPFPruned           args=[1024, 5, 3, True]
#     [10] n=2 C2PSAPruned          args=[1024]
#     [11] n=1 nn.Upsample          args=['None', 2, 'nearest']
#     [12] n=1 Concat               args=[1]
#     [13] n=2 C3k2Pruned           args=[512, True]
#     [14] n=1 nn.Upsample          args=['None', 2, 'nearest']
#     [15] n=1 Concat               args=[1]
#     [16] n=2 C3k2Pruned           args=[256, True]
#     [17] n=1 Conv                 args=[256, 3, 2]
#     [18] n=1 Concat               args=[1]
#     [19] n=2 C3k2Pruned           args=[512, True]
#     [20] n=1 Conv                 args=[512, 3, 2]
#     [21] n=1 Concat               args=[1]
#     [22] n=1 C3k2PrunedAttn       args=[1024, True]
#     [23] n=1 DetectPruned         args=[10]
#   L1 Norm importance computed for 118 layers
#
# Step 7: Tạo pruning masks (divisor=8)...
# ==============================================================================================================
# Layer name                          | Origin |  Ratio |    Raw | Rounded | Sparsity | Note
# ==============================================================================================================
# model.0.bn                          |     64 |   0.50 |     31 |      32 |    0.500 |
# model.1.bn                          |    128 |   0.50 |     63 |      64 |    0.500 |
# model.2.cv1.bn                      |    128 |   0.50 |     63 |      64 |    0.500 |
# model.2.cv2.bn                      |    256 |   0.50 |    127 |     128 |    0.500 |
# model.2.m.0.cv1.bn                  |     32 |      - |      - |       - |        - | SKIP (residual)
# model.2.m.0.cv2.bn                  |     32 |   0.50 |     16 |      16 |    0.500 |
# model.2.m.0.cv3.bn                  |     64 |   0.50 |     31 |      32 |    0.500 |
# model.2.m.0.m.0.cv1.bn              |     32 |   0.50 |     16 |      16 |    0.500 |
# model.2.m.0.m.0.cv2.bn              |     32 |      - |      - |       - |        - | SKIP (residual)
# model.2.m.0.m.1.cv1.bn              |     32 |   0.50 |     16 |      16 |    0.500 |
# model.2.m.0.m.1.cv2.bn              |     32 |      - |      - |       - |        - | SKIP (residual)
# model.2.m.1.cv1.bn                  |     32 |      - |      - |       - |        - | SKIP (residual)
# model.2.m.1.cv2.bn                  |     32 |   0.50 |     16 |      16 |    0.500 |
# model.2.m.1.cv3.bn                  |     64 |   0.50 |     31 |      32 |    0.500 |
# model.2.m.1.m.0.cv1.bn              |     32 |   0.50 |     16 |      16 |    0.500 |
# model.2.m.1.m.0.cv2.bn              |     32 |      - |      - |       - |        - | SKIP (residual)
# model.2.m.1.m.1.cv1.bn              |     32 |   0.50 |     16 |      16 |    0.500 |
# model.2.m.1.m.1.cv2.bn              |     32 |      - |      - |       - |        - | SKIP (residual)
# model.3.bn                          |    256 |   0.50 |    127 |     128 |    0.500 |
# model.4.cv1.bn                      |    256 |   0.50 |    127 |     128 |    0.500 |
# model.4.cv2.bn                      |    512 |   0.50 |    255 |     256 |    0.500 |
# model.4.m.0.cv1.bn                  |     64 |      - |      - |       - |        - | SKIP (residual)
# model.4.m.0.cv2.bn                  |     64 |   0.50 |     31 |      32 |    0.500 |
# model.4.m.0.cv3.bn                  |    128 |   0.50 |     63 |      64 |    0.500 |
# model.4.m.0.m.0.cv1.bn              |     64 |   0.50 |     31 |      32 |    0.500 |
# model.4.m.0.m.0.cv2.bn              |     64 |      - |      - |       - |        - | SKIP (residual)
# model.4.m.0.m.1.cv1.bn              |     64 |   0.50 |     31 |      32 |    0.500 |
# model.4.m.0.m.1.cv2.bn              |     64 |      - |      - |       - |        - | SKIP (residual)
# model.4.m.1.cv1.bn                  |     64 |      - |      - |       - |        - | SKIP (residual)
# model.4.m.1.cv2.bn                  |     64 |   0.50 |     31 |      32 |    0.500 |
# model.4.m.1.cv3.bn                  |    128 |   0.50 |     63 |      64 |    0.500 |
# model.4.m.1.m.0.cv1.bn              |     64 |   0.50 |     31 |      32 |    0.500 |
# model.4.m.1.m.0.cv2.bn              |     64 |      - |      - |       - |        - | SKIP (residual)
# model.4.m.1.m.1.cv1.bn              |     64 |   0.50 |     31 |      32 |    0.500 |
# model.4.m.1.m.1.cv2.bn              |     64 |      - |      - |       - |        - | SKIP (residual)
# model.5.bn                          |    512 |   0.50 |    255 |     256 |    0.500 |
# model.6.cv1.bn                      |    512 |   0.50 |    255 |     256 |    0.500 |
# model.6.cv2.bn                      |    512 |   0.50 |    255 |     256 |    0.500 |
# model.6.m.0.cv1.bn                  |    128 |      - |      - |       - |        - | SKIP (residual)
# model.6.m.0.cv2.bn                  |    128 |   0.50 |     63 |      64 |    0.500 |
# model.6.m.0.cv3.bn                  |    256 |   0.50 |    127 |     128 |    0.500 |
# model.6.m.0.m.0.cv1.bn              |    128 |   0.50 |     63 |      64 |    0.500 |
# model.6.m.0.m.0.cv2.bn              |    128 |      - |      - |       - |        - | SKIP (residual)
# model.6.m.0.m.1.cv1.bn              |    128 |   0.50 |     63 |      64 |    0.500 |
# model.6.m.0.m.1.cv2.bn              |    128 |      - |      - |       - |        - | SKIP (residual)
# model.6.m.1.cv1.bn                  |    128 |      - |      - |       - |        - | SKIP (residual)
# model.6.m.1.cv2.bn                  |    128 |   0.50 |     63 |      64 |    0.500 |
# model.6.m.1.cv3.bn                  |    256 |   0.50 |    127 |     128 |    0.500 |
# model.6.m.1.m.0.cv1.bn              |    128 |   0.50 |     63 |      64 |    0.500 |
# model.6.m.1.m.0.cv2.bn              |    128 |      - |      - |       - |        - | SKIP (residual)
# model.6.m.1.m.1.cv1.bn              |    128 |   0.50 |     63 |      64 |    0.500 |
# model.6.m.1.m.1.cv2.bn              |    128 |      - |      - |       - |        - | SKIP (residual)
# model.7.bn                          |    512 |   0.50 |    255 |     256 |    0.500 |
# model.8.cv1.bn                      |    512 |   0.50 |    255 |     256 |    0.500 |
# model.8.cv2.bn                      |    512 |   0.50 |    255 |     256 |    0.500 |
# model.8.m.0.cv1.bn                  |    128 |      - |      - |       - |        - | SKIP (residual)
# model.8.m.0.cv2.bn                  |    128 |   0.50 |     63 |      64 |    0.500 |
# model.8.m.0.cv3.bn                  |    256 |   0.50 |    127 |     128 |    0.500 |
# model.8.m.0.m.0.cv1.bn              |    128 |   0.50 |     63 |      64 |    0.500 |
# model.8.m.0.m.0.cv2.bn              |    128 |      - |      - |       - |        - | SKIP (residual)
# model.8.m.0.m.1.cv1.bn              |    128 |   0.50 |     63 |      64 |    0.500 |
# model.8.m.0.m.1.cv2.bn              |    128 |      - |      - |       - |        - | SKIP (residual)
# model.8.m.1.cv1.bn                  |    128 |      - |      - |       - |        - | SKIP (residual)
# model.8.m.1.cv2.bn                  |    128 |   0.50 |     63 |      64 |    0.500 |
# model.8.m.1.cv3.bn                  |    256 |   0.50 |    127 |     128 |    0.500 |
# model.8.m.1.m.0.cv1.bn              |    128 |   0.50 |     63 |      64 |    0.500 |
# model.8.m.1.m.0.cv2.bn              |    128 |      - |      - |       - |        - | SKIP (residual)
# model.8.m.1.m.1.cv1.bn              |    128 |   0.50 |     63 |      64 |    0.500 |
# model.8.m.1.m.1.cv2.bn              |    128 |      - |      - |       - |        - | SKIP (residual)
# model.9.cv1.bn                      |    256 |   0.50 |    127 |     128 |    0.500 |
# model.9.cv2.bn                      |    512 |   0.50 |    255 |     256 |    0.500 |
# model.10.cv1.bn                     |    512 |      - |      - |       - |        - | SKIP (residual)
# model.10.cv2.bn                     |    512 |   0.50 |    255 |     256 |    0.500 |
# model.10.m.0.attn.qkv.bn            |    512 |      - |      - |       - |        - | SKIP (residual)
# model.10.m.0.attn.proj.bn           |    256 |      - |      - |       - |        - | SKIP (residual)
# model.10.m.0.attn.pe.bn             |    256 |      - |      - |       - |        - | SKIP (residual)
# model.10.m.0.ffn.0.bn               |    512 |      - |      - |       - |        - | SKIP (residual)
# model.10.m.0.ffn.1.bn               |    256 |      - |      - |       - |        - | SKIP (residual)
# model.10.m.1.attn.qkv.bn            |    512 |      - |      - |       - |        - | SKIP (residual)
# model.10.m.1.attn.proj.bn           |    256 |      - |      - |       - |        - | SKIP (residual)
# model.10.m.1.attn.pe.bn             |    256 |      - |      - |       - |        - | SKIP (residual)
# model.10.m.1.ffn.0.bn               |    512 |      - |      - |       - |        - | SKIP (residual)
# model.10.m.1.ffn.1.bn               |    256 |      - |      - |       - |        - | SKIP (residual)
# model.13.cv1.bn                     |    512 |   0.50 |    255 |     256 |    0.500 |
# model.13.cv2.bn                     |    512 |   0.50 |    255 |     256 |    0.500 |
# model.13.m.0.cv1.bn                 |    128 |      - |      - |       - |        - | SKIP (residual)
# model.13.m.0.cv2.bn                 |    128 |   0.50 |     63 |      64 |    0.500 |
# model.13.m.0.cv3.bn                 |    256 |   0.50 |    127 |     128 |    0.500 |
# model.13.m.0.m.0.cv1.bn             |    128 |   0.50 |     63 |      64 |    0.500 |
# model.13.m.0.m.0.cv2.bn             |    128 |      - |      - |       - |        - | SKIP (residual)
# model.13.m.0.m.1.cv1.bn             |    128 |   0.50 |     63 |      64 |    0.500 |
# model.13.m.0.m.1.cv2.bn             |    128 |      - |      - |       - |        - | SKIP (residual)
# model.13.m.1.cv1.bn                 |    128 |      - |      - |       - |        - | SKIP (residual)
# model.13.m.1.cv2.bn                 |    128 |   0.50 |     63 |      64 |    0.500 |
# model.13.m.1.cv3.bn                 |    256 |   0.50 |    127 |     128 |    0.500 |
# model.13.m.1.m.0.cv1.bn             |    128 |   0.50 |     63 |      64 |    0.500 |
# model.13.m.1.m.0.cv2.bn             |    128 |      - |      - |       - |        - | SKIP (residual)
# model.13.m.1.m.1.cv1.bn             |    128 |   0.50 |     63 |      64 |    0.500 |
# model.13.m.1.m.1.cv2.bn             |    128 |      - |      - |       - |        - | SKIP (residual)
# model.16.cv1.bn                     |    256 |   0.50 |    127 |     128 |    0.500 |
# model.16.cv2.bn                     |    256 |   0.50 |    127 |     128 |    0.500 |
# model.16.m.0.cv1.bn                 |     64 |      - |      - |       - |        - | SKIP (residual)
# model.16.m.0.cv2.bn                 |     64 |   0.50 |     31 |      32 |    0.500 |
# model.16.m.0.cv3.bn                 |    128 |   0.50 |     63 |      64 |    0.500 |
# model.16.m.0.m.0.cv1.bn             |     64 |   0.50 |     31 |      32 |    0.500 |
# model.16.m.0.m.0.cv2.bn             |     64 |      - |      - |       - |        - | SKIP (residual)
# model.16.m.0.m.1.cv1.bn             |     64 |   0.50 |     31 |      32 |    0.500 |
# model.16.m.0.m.1.cv2.bn             |     64 |      - |      - |       - |        - | SKIP (residual)
# model.16.m.1.cv1.bn                 |     64 |      - |      - |       - |        - | SKIP (residual)
# model.16.m.1.cv2.bn                 |     64 |   0.50 |     31 |      32 |    0.500 |
# model.16.m.1.cv3.bn                 |    128 |   0.50 |     63 |      64 |    0.500 |
# model.16.m.1.m.0.cv1.bn             |     64 |   0.50 |     31 |      32 |    0.500 |
# model.16.m.1.m.0.cv2.bn             |     64 |      - |      - |       - |        - | SKIP (residual)
# model.16.m.1.m.1.cv1.bn             |     64 |   0.50 |     31 |      32 |    0.500 |
# model.16.m.1.m.1.cv2.bn             |     64 |      - |      - |       - |        - | SKIP (residual)
# model.17.bn                         |    256 |   0.50 |    127 |     128 |    0.500 |
# model.19.cv1.bn                     |    512 |   0.50 |    255 |     256 |    0.500 |
# model.19.cv2.bn                     |    512 |   0.50 |    255 |     256 |    0.500 |
# model.19.m.0.cv1.bn                 |    128 |      - |      - |       - |        - | SKIP (residual)
# model.19.m.0.cv2.bn                 |    128 |   0.50 |     63 |      64 |    0.500 |
# model.19.m.0.cv3.bn                 |    256 |   0.50 |    127 |     128 |    0.500 |
# model.19.m.0.m.0.cv1.bn             |    128 |   0.50 |     63 |      64 |    0.500 |
# model.19.m.0.m.0.cv2.bn             |    128 |      - |      - |       - |        - | SKIP (residual)
# model.19.m.0.m.1.cv1.bn             |    128 |   0.50 |     63 |      64 |    0.500 |
# model.19.m.0.m.1.cv2.bn             |    128 |      - |      - |       - |        - | SKIP (residual)
# model.19.m.1.cv1.bn                 |    128 |      - |      - |       - |        - | SKIP (residual)
# model.19.m.1.cv2.bn                 |    128 |   0.50 |     63 |      64 |    0.500 |
# model.19.m.1.cv3.bn                 |    256 |   0.50 |    127 |     128 |    0.500 |
# model.19.m.1.m.0.cv1.bn             |    128 |   0.50 |     63 |      64 |    0.500 |
# model.19.m.1.m.0.cv2.bn             |    128 |      - |      - |       - |        - | SKIP (residual)
# model.19.m.1.m.1.cv1.bn             |    128 |   0.50 |     63 |      64 |    0.500 |
# model.19.m.1.m.1.cv2.bn             |    128 |      - |      - |       - |        - | SKIP (residual)
# model.20.bn                         |    512 |   0.50 |    255 |     256 |    0.500 |
# model.22.cv1.bn                     |    512 |      - |      - |       - |        - | SKIP (residual)
# model.22.cv2.bn                     |    512 |   0.50 |    255 |     256 |    0.500 |
# model.22.m.0.0.cv1.bn               |    128 |   0.50 |     63 |      64 |    0.500 |
# model.22.m.0.0.cv2.bn               |    256 |      - |      - |       - |        - | SKIP (residual)
# model.22.m.0.1.attn.qkv.bn          |    512 |      - |      - |       - |        - | SKIP (residual)
# model.22.m.0.1.attn.proj.bn         |    256 |      - |      - |       - |        - | SKIP (residual)
# model.22.m.0.1.attn.pe.bn           |    256 |      - |      - |       - |        - | SKIP (residual)
# model.22.m.0.1.ffn.0.bn             |    512 |      - |      - |       - |        - | SKIP (residual)
# model.22.m.0.1.ffn.1.bn             |    256 |      - |      - |       - |        - | SKIP (residual)
# model.23.cv2.0.0.bn                 |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.cv2.0.1.bn                 |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.cv2.1.0.bn                 |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.cv2.1.1.bn                 |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.cv2.2.0.bn                 |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.cv2.2.1.bn                 |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.cv3.0.0.0.bn               |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.cv3.0.0.1.bn               |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.cv3.0.1.0.bn               |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.cv3.0.1.1.bn               |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.cv3.1.0.0.bn               |    512 |   0.50 |    255 |     256 |    0.500 |
# model.23.cv3.1.0.1.bn               |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.cv3.1.1.0.bn               |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.cv3.1.1.1.bn               |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.cv3.2.0.0.bn               |    512 |   0.50 |    255 |     256 |    0.500 |
# model.23.cv3.2.0.1.bn               |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.cv3.2.1.0.bn               |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.cv3.2.1.1.bn               |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.one2one_cv2.0.0.bn         |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.one2one_cv2.0.1.bn         |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.one2one_cv2.1.0.bn         |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.one2one_cv2.1.1.bn         |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.one2one_cv2.2.0.bn         |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.one2one_cv2.2.1.bn         |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.one2one_cv3.0.0.0.bn       |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.one2one_cv3.0.0.1.bn       |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.one2one_cv3.0.1.0.bn       |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.one2one_cv3.0.1.1.bn       |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.one2one_cv3.1.0.0.bn       |    512 |   0.50 |    255 |     256 |    0.500 |
# model.23.one2one_cv3.1.0.1.bn       |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.one2one_cv3.1.1.0.bn       |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.one2one_cv3.1.1.1.bn       |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.one2one_cv3.2.0.0.bn       |    512 |   0.50 |    255 |     256 |    0.500 |
# model.23.one2one_cv3.2.0.1.bn       |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.one2one_cv3.2.1.0.bn       |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.one2one_cv3.2.1.1.bn       |    256 |   0.50 |    127 |     128 |    0.500 |
# ==============================================================================================================
#
# Step 8: Validate divisibility...
#   ✅ Tất cả layers đều chia hết cho 8!
#
# Step 9: Build pruned model...
#
#                    from  n    params  module                                            arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv                  [32, 64, 3, 2]
#   2                  -1  2     65104  ultralytics.nn.modules.block_pruned.C3k2Pruned    [64, 64, [21, 43], [32, 32], [16, 16], [32, 32], [[16, 16], [16, 16]], [[32, 32], [32, 32]], [2, 2], 128, 2, 2, True]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv                  [128, 128, 3, 2]
#   4                  -1  2    258432  ultralytics.nn.modules.block_pruned.C3k2Pruned    [128, 128, [40, 88], [64, 64], [32, 32], [64, 64], [[32, 32], [32, 32]], [[64, 64], [64, 64]], [2, 2], 256, 2, 2, True]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv                  [256, 256, 3, 2]
#   6                  -1  2    898560  ultralytics.nn.modules.block_pruned.C3k2Pruned    [256, 256, [76, 180], [128, 128], [64, 64], [128, 128], [[64, 64], [64, 64]], [[128, 128], [128, 128]], [2, 2], 256, 2, 2, True]
#   7                  -1  1    590336  ultralytics.nn.modules.conv.Conv                  [256, 256, 3, 2]
#   8                  -1  2    885696  ultralytics.nn.modules.block_pruned.C3k2Pruned    [256, 256, [143, 113], [128, 128], [64, 64], [128, 128], [[64, 64], [64, 64]], [[128, 128], [128, 128]], [2, 2], 256, 2, 2, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block_pruned.SPPFPruned    [256, 128, 256, 5, 3, True]
#  10                  -1  2   1192960  ultralytics.nn.modules.block_pruned.C2PSAPruned   [256, 512, [256, 256], 256, 2, 0.5]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample              [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat                [1]
#  13                  -1  2    954688  ultralytics.nn.modules.block_pruned.C3k2Pruned    [512, 256, [125, 131], [128, 128], [64, 64], [128, 128], [[64, 64], [64, 64]], [[128, 128], [128, 128]], [2, 2], 256, 2, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample              [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat                [1]
#  16                  -1  2    277440  ultralytics.nn.modules.block_pruned.C3k2Pruned    [512, 128, [10, 118], [64, 64], [32, 32], [64, 64], [[32, 32], [32, 32]], [[64, 64], [64, 64]], [2, 2], 128, 2, 2, True]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv                  [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat                [1]
#  19                  -1  2    923264  ultralytics.nn.modules.block_pruned.C3k2Pruned    [384, 256, [118, 138], [128, 128], [64, 64], [128, 128], [[64, 64], [64, 64]], [[128, 128], [128, 128]], [2, 2], 256, 2, 2, True]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv                  [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat                [1]
#  22                  -1  1   1220480  ultralytics.nn.modules.block_pruned.C3k2PrunedAttn[512, 512, [256, 256], 1, [64], 256, True]
#  23        [16, 19, 22]  1    720980  ultralytics.nn.modules.head_pruned.DetectPruned   [[32, 32, 32], [32, 32, 32], [128, 256, 256], [128, 128, 128], [128, 128, 128], [128, 128, 128], [32, 32, 32], [32, 32, 32], [128, 256, 256], [128, 128, 128], [128, 128, 128], [128, 128, 128], 10, 1, (128, 256, 256)]
# Model summary: 390 layers, 9,648,132 parameters, 9,648,132 gradients, 31.7 GFLOPs
#
#
# Step 10: Copy weights từ original model...
#    Copy weights hoàn tất!
#
# Step 11: Save pruned model...
#    Model saved: /kaggle/working/yolo/weights/best_l1norm_div8.pt
#
# Testing forward pass...
#    Forward pass successful!
#
# ====================================================================================================
#  PRUNING SUMMARY (l1norm)
# ====================================================================================================
# Method:            l1norm
# Divisor:           8
# Prune ratio:       0.500
# Total channels:    35,264 → 22,976
# Compression:       1.53x
# Model saved:       /kaggle/working/yolo/weights/best_l1norm_div8.pt
# ====================================================================================================
#
#  PRUNING HOÀN TẤT!
#
# -> /kaggle/working/yolo/weights/yolo26l_vd_pruned50.pt

# %% [markdown]
# ## 6. Finetune + CWD

# %%
if n_base < 100 or not PRUNED.exists():
    print("Bo qua: chua co model da prune.")
    n_ours = 0
else:
    # Teacher la baseline cua chinh size nay.
    n_ours = V.train(OURS_NAME, str(PRUNED),
                     finetune=True,      # build DetectionModelPruned tu maskbndict
                     kd=True, kd_teacher=str(BEST_BASE), kd_method="cwd",
                     kd_lambda=0.5, kd_layers="neck", kd_warmup=5,
                     cwd_temperature=9.0)
# Out:
# [vd_oursl] resume tu epoch 42
# New https://pypi.org/project/ultralytics/8.4.163 available 😃 Update with 'pip install -U ultralytics'
# [Resume] Found custom_training_args in checkpoint: ['sr', 'dms', 'dms_target', 'dms_lambda', 'dms_lr', 'dms_taylor_type', 'dms_decay_ratio', 'dms_grad_scale', 'finetune', 'kd', 'kd_teacher', 'kd_lambda', 'cwd_temperature', 'kd_layers', 'kd_warmup', 'cwd_learnable_tau_lr', 'cwd_learnable_tau_init', 'kd_method', 'mgd_mask_ratio', 'fitnets_normalize']
# Ultralytics 8.4.14 🚀 Python-3.12.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 14912MiB)
#                                                       CUDA:1 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, cwd_learnable_tau_init=9.0, cwd_learnable_tau_lr=0.001, cwd_projection=False, cwd_tau_reg=0.1, cwd_temperature=9.0, data=/kaggle/working/yolo/ultralytics/cfg/datasets/VisDrone.yaml, degrees=0.0, deterministic=True, device=0,1, dfl=1.5, dms=False, dms_decay_ratio=1, dms_grad_scale=-1.0, dms_lambda=1.0, dms_lr=2e-05, dms_target=0.3, dms_taylor_type=taylor, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, finetune=True, fitnets_normalize=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, kd=True, kd_lambda=0.5, kd_layers=neck, kd_method=cwd, kd_teacher=/kaggle/working/yolo/runs/vd_yolo26l/weights/best.pt, kd_warmup=5, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mgd_mask_ratio=0.5, mixup=0.0, mode=train, model=/kaggle/working/yolo/runs/vd_oursl/weights/last.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=vd_oursl, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/yolo/runs, rect=False, resume=/kaggle/working/yolo/runs/vd_oursl/weights/last.pt, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/yolo/runs/vd_oursl, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, sr=None, stop_after_h=10.0, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
# WARNING ⚠️ Dataset '/kaggle/working/yolo/ultralytics/cfg/datasets/VisDrone.yaml' images not found, missing path '/kaggle/working/datasets/VisDrone/images/val'
# Downloading 3 file(s) with 4 threads to /kaggle/working/datasets/VisDrone...
# Downloading https://ultralytics.com/assets/VisDrone2019-DET-val.zip to '/kaggle/working/datasets/VisDrone/VisDrone2019-DET-val.zip': 100% ━━━━━━━━━━━━ 77.9MB 147.9MB/s 0.5s
# Downloading https://ultralytics.com/assets/VisDrone2019-DET-test-dev.zip to '/kaggle/working/datasets/VisDrone/VisDrone2019-DET-test-dev.zip': 100% ━━━━━━━━━━━━ 296.8MB 201.6MB/s 1.5s
# Unzipping /kaggle/working/datasets/VisDrone/VisDrone2019-DET-val.zip to /kaggle/working/datasets/VisDrone/VisDrone2019-DET-val...: 100% ━━━━━━━━━━━━ 1099/1099 1.1Kfiles/s 1.0s
# Unzipping /kaggle/working/datasets/VisDrone/VisDrone2019-DET-test-dev.zip to /kaggle/working/datasets/VisDrone/VisDrone2019-DET-test-dev...: 100% ━━━━━━━━━━━━ 3223/3223 1.4Kfiles/s 2.3s
# Downloading https://ultralytics.com/assets/VisDrone2019-DET-train.zip to '/kaggle/working/datasets/VisDrone/VisDrone2019-DET-train.zip': 100% ━━━━━━━━━━━━ 1.4GB 240.1MB/s 6.2s
# Unzipping /kaggle/working/datasets/VisDrone/VisDrone2019-DET-train.zip to /kaggle/working/datasets/VisDrone/VisDrone2019-DET-train...: 100% ━━━━━━━━━━━━ 12945/12945 2.0Kfiles/s 6.4s
# Converting train: ━━━━━━━━━━━━ 6471 2.2Kit/s 3.2s
# Converting val: ━━━━━━━━━━━━ 548 1.4Kit/s 0.3s
# Converting test: ━━━━━━━━━━━━ 1610 2.2Kit/s 0.7s
# Dataset download success ✅ (17.7s), saved to /kaggle/working/datasets
#
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 15.1MB/s 0.0s
# DDP: debug command /usr/bin/python3 -m torch.distributed.run --nproc_per_node 2 --master_port 55647 /root/.config/Ultralytics/DDP/_temp_ywl1jfsu137944825776608.py
# Ultralytics 8.4.14 🚀 Python-3.12.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 14912MiB)
#                                                       CUDA:1 (Tesla T4, 14912MiB)
# Finetune mode: building DetectionModelPruned with maskbndict
# Transferred 1092/1092 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 66.5MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2494.8±1097.7 MB/s, size: 206.8 KB)
# train: Scanning /kaggle/working/datasets/VisDrone/labels/train... 6471 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6471/6471 1.1Kit/s 5.8s
# train: /kaggle/working/datasets/VisDrone/images/train/0000137_02220_d_0000163.jpg: 1 duplicate labels removed
# train: /kaggle/working/datasets/VisDrone/images/train/0000140_00118_d_0000002.jpg: 1 duplicate labels removed
# train: /kaggle/working/datasets/VisDrone/images/train/9999945_00000_d_0000114.jpg: 1 duplicate labels removed
# train: /kaggle/working/datasets/VisDrone/images/train/9999987_00000_d_0000049.jpg: 1 duplicate labels removed
# train: New cache created: /kaggle/working/datasets/VisDrone/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1484.2±1352.3 MB/s, size: 136.5 KB)
# val: Scanning /kaggle/working/datasets/VisDrone/labels/val... 548 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 548/548 1.0Kit/s 0.5s
# val: New cache created: /kaggle/working/datasets/VisDrone/labels/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.01, momentum=0.9) with parameter groups 178 weight(decay=0.0), 190 weight(decay=0.0005), 190 bias(decay=0.0)
# Plotting labels to /kaggle/working/yolo/runs/vd_oursl/labels.jpg...
# Resuming training /kaggle/working/yolo/runs/vd_oursl/weights/last.pt from epoch 43 to 100 total epochs
# [KD] Channel masks: 4 layers have mismatch
# [KD] ENABLED: method=cwd, teacher=/kaggle/working/yolo/runs/vd_yolo26l/weights/best.pt, lambda=0.5
# [KD] layers=['model.13', 'model.16', 'model.19', 'model.22'], temp=fixed
# [KD] Resuming KD training...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/yolo/runs/vd_oursl
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      6.89G      1.833       1.15   0.002123        360        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:13
# [CWD] Epoch 42: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.9it/s 4.6s
#                    all        548      38759      0.522      0.417      0.431      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100       6.9G      1.815      1.131    0.00212        301        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:18
# [CWD] Epoch 43: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s
#                    all        548      38759      0.528       0.42      0.435       0.26
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      6.98G      1.803      1.128   0.002118        278        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:18
# [CWD] Epoch 44: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                    all        548      38759      0.534      0.417      0.433       0.26
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      7.02G      1.807      1.128   0.002086        451        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:19
# [CWD] Epoch 45: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                    all        548      38759      0.538      0.408       0.43      0.258
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      7.88G      1.813      1.124     0.0021        534        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:19
# [CWD] Epoch 46: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.8s
#                    all        548      38759       0.54      0.411      0.434      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      5.53G      1.816      1.123   0.002078        387        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:19
# [CWD] Epoch 47: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                    all        548      38759      0.533      0.416      0.431      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      6.88G      1.811      1.129   0.002076        362        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:18
# [CWD] Epoch 48: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.8it/s 3.7s
#                    all        548      38759      0.529      0.413      0.431      0.258
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      6.93G      1.803      1.112   0.002067        299        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:16
# [CWD] Epoch 49: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                    all        548      38759      0.541      0.411      0.433       0.26
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      6.97G      1.809      1.117   0.002088        526        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:19
# [CWD] Epoch 50: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.5it/s 4.0s
#                    all        548      38759       0.55      0.416       0.44      0.262
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      6.99G      1.797      1.106   0.002091        291        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:18
# [CWD] Epoch 51: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                    all        548      38759      0.537      0.422      0.438      0.262
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      7.06G      1.814      1.112   0.002077        458        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:18
# [CWD] Epoch 52: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                    all        548      38759      0.539      0.424      0.441      0.265
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      7.11G      1.786      1.094   0.002056        277        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:21
# [CWD] Epoch 53: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.8it/s 3.7s
#                    all        548      38759      0.535      0.428      0.439      0.262
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      7.15G      1.785      1.097   0.002067        305        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:19
# [CWD] Epoch 54: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.8it/s 3.8s
#                    all        548      38759      0.541      0.429      0.443      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      7.17G      1.786      1.102     0.0021        235        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:19
# [CWD] Epoch 55: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                    all        548      38759      0.543      0.426      0.439      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      7.24G      1.775       1.09   0.002046        321        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:19
# [CWD] Epoch 56: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.8it/s 3.7s
#                    all        548      38759      0.537       0.42      0.436      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      7.28G      1.794      1.097   0.002072        184        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:18
# [CWD] Epoch 57: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.8it/s 3.8s
#                    all        548      38759      0.527      0.423      0.436      0.265
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      6.51G      1.792      1.098   0.002056        330        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:18
# [CWD] Epoch 58: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                    all        548      38759      0.551      0.417      0.436      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100         7G      1.775      1.081   0.002047        352        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:19
# [CWD] Epoch 59: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.8it/s 3.7s
#                    all        548      38759      0.537      0.424      0.436      0.262
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      7.55G      1.775      1.078   0.002053        262        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:19
# [CWD] Epoch 60: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                    all        548      38759      0.533      0.424      0.436      0.262
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      6.23G      1.775      1.087   0.002059        436        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:18
# [CWD] Epoch 61: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.6it/s 3.9s
#                    all        548      38759      0.546      0.422       0.44      0.265
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      6.74G       1.78      1.084   0.002042        296        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:20
# [CWD] Epoch 62: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.8it/s 3.7s
#                    all        548      38759       0.55      0.425       0.44      0.265
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      8.03G      1.775      1.073   0.002046        236        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:17
# [CWD] Epoch 63: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                    all        548      38759       0.55      0.423      0.438      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      5.98G       1.77       1.07   0.002039        430        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:17
# [CWD] Epoch 64: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.8it/s 3.8s
#                    all        548      38759      0.542      0.424      0.438      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      7.25G      1.767       1.07   0.002027        448        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:21
# [CWD] Epoch 65: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.8it/s 3.7s
#                    all        548      38759      0.546      0.426      0.442      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100       7.3G      1.769      1.066   0.002023        359        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:21
# [CWD] Epoch 66: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.8s
#                    all        548      38759      0.549      0.421      0.442      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      6.83G      1.751       1.05   0.002004        261        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:19
# [CWD] Epoch 67: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.8it/s 3.8s
#                    all        548      38759      0.555      0.422      0.444      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      8.21G      1.767      1.058   0.001982        157        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:19
# [CWD] Epoch 68: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                    all        548      38759      0.549      0.428      0.447      0.269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      5.84G      1.767      1.057   0.001988        202        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:17
# [CWD] Epoch 69: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.0it/s 3.6s
#                    all        548      38759      0.551      0.426      0.443      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      6.99G      1.749      1.051   0.002014        289        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:18
# [CWD] Epoch 70: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.8s
#                    all        548      38759       0.56      0.425      0.445      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      7.01G       1.75      1.044   0.002004        132        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:17
# [CWD] Epoch 71: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.8it/s 3.8s
#                    all        548      38759      0.556      0.425      0.443      0.265
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      7.08G      1.768      1.051   0.001988        394        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:19
# [CWD] Epoch 72: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.6it/s 4.0s
#                    all        548      38759      0.549      0.425      0.445      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      7.12G      1.748      1.042   0.001963        268        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:22
# [CWD] Epoch 73: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.6it/s 3.9s
#                    all        548      38759      0.554      0.427      0.444      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      7.83G      1.759      1.036    0.00197        285        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:19
# [CWD] Epoch 74: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                    all        548      38759      0.551      0.424      0.443      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      6.12G      1.731      1.026   0.001981         83        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:19
# [CWD] Epoch 75: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                    all        548      38759      0.562      0.416      0.442      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      7.18G      1.734      1.027   0.001947        442        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:20
# [CWD] Epoch 76: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.6it/s 3.9s
#                    all        548      38759      0.548      0.427      0.444      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100         8G      1.745      1.036   0.001958         83        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:21
# [CWD] Epoch 77: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.8it/s 3.8s
#                    all        548      38759      0.553      0.422      0.442      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      7.81G      1.743      1.026    0.00196        632        640: 100% ━━━━━━━━━━━━ 405/405 1.2it/s 5:28
# [CWD] Epoch 78: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                    all        548      38759      0.536      0.433      0.442      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      5.55G      1.733      1.018   0.001955        113        640: 100% ━━━━━━━━━━━━ 405/405 1.2it/s 5:26
# [CWD] Epoch 79: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.6it/s 3.9s
#                    all        548      38759      0.552      0.426      0.442      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      6.49G       1.72      1.012   0.001942        362        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:23
# [CWD] Epoch 80: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.9s
#                    all        548      38759      0.555      0.426      0.443      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      6.53G      1.723      1.014   0.001971        350        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:23
# [CWD] Epoch 81: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.4it/s 4.1s
#                    all        548      38759      0.549      0.428      0.443      0.265
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      6.58G       1.72      1.004   0.001914        373        640: 100% ━━━━━━━━━━━━ 405/405 1.2it/s 5:26
# [CWD] Epoch 82: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.9s
#                    all        548      38759      0.549      0.427      0.443      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      6.59G      1.698     0.9874   0.001923        369        640: 100% ━━━━━━━━━━━━ 405/405 1.2it/s 5:25
# [CWD] Epoch 83: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.6it/s 3.9s
#                    all        548      38759      0.547      0.429      0.442      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      7.13G      1.724      1.006   0.001908        333        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:23
# [CWD] Epoch 84: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.8s
#                    all        548      38759      0.557      0.423      0.442      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      7.18G      1.702     0.9849   0.001914        182        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:22
# [CWD] Epoch 85: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.8s
#                    all        548      38759      0.557      0.424      0.444      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      7.78G      1.717      1.003   0.001922        158        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:23
# [CWD] Epoch 86: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.9s
#                    all        548      38759      0.554      0.425      0.444      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      6.48G      1.708     0.9913   0.001917        332        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:23
# [CWD] Epoch 87: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.8s
#                    all        548      38759      0.551      0.427      0.444      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      7.01G      1.711     0.9897   0.001882        285        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:24
# [CWD] Epoch 88: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.8s
#                    all        548      38759      0.557      0.426      0.444      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      7.01G      1.697     0.9859   0.001899        222        640: 100% ━━━━━━━━━━━━ 405/405 1.2it/s 5:24
# [CWD] Epoch 89: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.8s
#                    all        548      38759       0.56      0.429      0.444      0.267
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      7.05G      1.642     0.9356    0.00195        281        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:18
# [CWD] Epoch 90: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.6it/s 3.9s
#                    all        548      38759      0.547       0.43      0.441      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      7.07G      1.626      0.922   0.001937        273        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:16
# [CWD] Epoch 91: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.6it/s 3.9s
#                    all        548      38759      0.544      0.428       0.44      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      7.92G      1.639     0.9248   0.001942        191        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:18
# [CWD] Epoch 92: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                    all        548      38759      0.555      0.425      0.439      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      6.09G      1.622     0.9184   0.001924        171        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:20
# [CWD] Epoch 93: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.9s
#                    all        548      38759      0.544      0.428      0.438      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      6.09G      1.623     0.9168   0.001932         76        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:18
# [CWD] Epoch 94: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.8s
#                    all        548      38759      0.554      0.423      0.438      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      6.59G      1.598     0.9017   0.001928        204        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:17
# [CWD] Epoch 95: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.8s
#                    all        548      38759      0.554      0.425      0.438      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      6.62G      1.612     0.9065   0.001909        129        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:17
# [CWD] Epoch 96: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.6it/s 3.9s
#                    all        548      38759      0.548      0.428      0.437      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      6.66G      1.619     0.9104   0.001914        175        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:21
# [CWD] Epoch 97: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.5it/s 4.0s
#                    all        548      38759       0.54      0.426      0.436      0.262
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100       7.2G      1.605     0.9027   0.001919        161        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:19
# [CWD] Epoch 98: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.6it/s 3.9s
#                    all        548      38759      0.541      0.425      0.437      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      7.21G      1.603     0.8964   0.001883        142        640: 100% ━━━━━━━━━━━━ 405/405 1.3it/s 5:17
# [CWD] Epoch 99: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.8s
#                    all        548      38759      0.549      0.421      0.436      0.263
#
# 58 epochs completed in 5.227 hours.
# Optimizer stripped from /kaggle/working/yolo/runs/vd_oursl/weights/last.pt, 20.0MB
# Optimizer stripped from /kaggle/working/yolo/runs/vd_oursl/weights/best.pt, 20.0MB
#
# Validating /kaggle/working/yolo/runs/vd_oursl/weights/best.pt...
# Model summary (fused): 212 layers, 9,625,156 parameters, 0 gradients, 31.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 2.6it/s 6.9s
#                    all        548      38759       0.55      0.428      0.447      0.269
#             pedestrian        520       8844      0.617      0.468       0.52      0.247
#                 people        482       5125      0.554      0.355      0.396      0.161
#                bicycle        364       1287      0.343      0.199      0.194     0.0885
#                    car        515      14064       0.75      0.807      0.829      0.596
#                    van        421       1975      0.557      0.462      0.472      0.335
#                  truck        266        750      0.566      0.353      0.393      0.263
#               tricycle        337       1045      0.465      0.322       0.32      0.179
#        awning-tricycle        220        532      0.349      0.201      0.198      0.124
#                    bus        131        251      0.735      0.582      0.621      0.443
#                  motor        485       4886      0.563      0.529      0.531      0.251
# Speed: 0.1ms preprocess, 2.9ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /kaggle/working/yolo/runs/vd_oursl

# %% [markdown]
# ## 7. Ket qua

# %%
V.report(SIZE, BASE_NAME, OURS_NAME)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 14912MiB)
# YOLO26l summary (fused): 190 layers, 24,753,450 parameters, 0 gradients, 86.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1881.2±193.0 MB/s, size: 131.3 KB)
# val: Scanning /kaggle/working/datasets/VisDrone/labels/val.cache... 548 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 548/548 164.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.1it/s 16.4s
#                    all        548      38759      0.586      0.464      0.483      0.295
#             pedestrian        520       8844      0.657      0.521      0.572      0.283
#                 people        482       5125      0.594      0.392       0.43      0.182
#                bicycle        364       1287       0.43      0.228      0.233      0.106
#                    car        515      14064      0.785      0.819      0.846      0.617
#                    van        421       1975      0.574      0.489        0.5      0.359
#                  truck        266        750      0.593      0.419       0.45      0.301
#               tricycle        337       1045      0.473      0.397      0.365       0.21
#        awning-tricycle        220        532       0.37      0.218      0.196      0.126
#                    bus        131        251      0.787       0.59      0.674      0.492
#                  motor        485       4886      0.597      0.564      0.561      0.273
# Speed: 0.6ms preprocess, 20.7ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to /kaggle/working/yolo/runs/detect/val
# Ultralytics 8.4.14 🚀 Python-3.12.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 14912MiB)
# Model summary (fused): 212 layers, 9,625,156 parameters, 0 gradients, 31.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2070.4±412.8 MB/s, size: 159.3 KB)
# val: Scanning /kaggle/working/datasets/VisDrone/labels/val.cache... 548 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 548/548 209.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 3.0it/s 11.6s
#                    all        548      38759      0.548      0.428      0.447      0.269
#             pedestrian        520       8844      0.614      0.468       0.52      0.248
#                 people        482       5125      0.553      0.356      0.396      0.161
#                bicycle        364       1287      0.343        0.2      0.193     0.0891
#                    car        515      14064       0.75      0.808      0.829      0.597
#                    van        421       1975      0.554      0.462      0.472      0.335
#                  truck        266        750      0.564      0.354      0.393      0.264
#               tricycle        337       1045      0.464      0.322       0.32       0.18
#        awning-tricycle        220        532      0.347      0.201      0.198      0.124
#                    bus        131        251      0.729       0.58       0.62      0.443
#                  motor        485       4886      0.561      0.529       0.53      0.251
# Speed: 0.6ms preprocess, 10.2ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to /kaggle/working/yolo/runs/detect/val2
#
# | Model | Params (M) | AP50 | AP50-95 |
# |---|---:|---:|---:|
# | YOLO26-L | 24.75 | 48.27 | 29.49 |
# | Ours-L | 9.63 | 44.70 | 26.92 |
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_23/482915014.py in <cell line: 0>()
# ----> 1 V.report(SIZE, BASE_NAME, OURS_NAME)
#
# /kaggle/working/yolo/notebooks/share_visdrone/vd_common.py in report(size, base_name, ours_name)
#     207         lg.mkdir(parents=True, exist_ok=True)
#     208         shutil.copy2(_run(name) / "weights" / "best.pt", ck / (stem + ".pt"))
# --> 209         shutil.copy2(run_csv(name), lg / (stem + ".csv"))
#     210         saved += [ck / (stem + ".pt"), lg / (stem + ".csv")]
#     211
#
# /usr/lib/python3.12/shutil.py in copy2(src, dst, follow_symlinks)
#     473                 raise
#     474
# --> 475     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     476     copystat(src, dst, follow_symlinks=follow_symlinks)
#     477     return dst
#
# /usr/lib/python3.12/shutil.py in copyfile(src, dst, follow_symlinks)
#     258         os.symlink(os.readlink(src), dst)
#     259     else:
# --> 260         with open(src, 'rb') as fsrc:
#     261             try:
#     262                 with open(dst, 'wb') as fdst:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/yolo/runs/vd_yolo26l/results.csv'
