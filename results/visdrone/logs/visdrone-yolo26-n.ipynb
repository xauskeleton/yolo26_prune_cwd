# %% [markdown]
# # VisDrone — yolo26**n**
#
# Lam tron mot size: baseline -> prune 50% -> finetune + CWD -> val.
# Ket qua la **hai dong** cua bang: `YOLO26-N` va `Ours-N`.
#
# | | |
# |---|---|
# | Baseline | `yolo26n.pt` (COCO), 100 epoch tren VisDrone |
# | Ours | L1-norm uniform 50% (div 8) + 100 epoch CWD tau=9, kd_layers=neck |
# | Batch / imgsz / seed | 16 / 640 / 0 |
# | cos_lr / patience / warmup | False / 100 / 3.0 |
# | Uoc tinh | ~2-3h, **1 phien** |
#
# > Bon notebook n/s/m/l dung **y het** cac tham so nay. Doi mot cai thoi la
# > ca bang het so sanh duoc. Dung sua `EPOCHS`, `BATCH`, `IMGSZ`, `RATIO`.
#
# ## Cach chay
#
# 1. Settings -> Accelerator **GPU T4 x2**, **Internet: On**
#    (can Internet: VisDrone 2.3 GB va `yolo26n.pt` deu tai tu mang)
# 2. Bam **Save & Run All**. Lan dau khong can Add Data.
# 3. Phien tu dung o 10h. Cell cuoi bao con thieu bao nhieu epoch -> Add Data
#    output cua chinh lan chay nay roi Save & Run All lai. Lap den khi bao `XONG`.
# 4. Xong thi gui lai bang 2 dong o cell cuoi.
#
# Notebook chay tuan tu baseline roi moi den Ours. Neu het gio giua chung, cac
# cell sau tu bo qua va in ra con thieu gi — khong bao loi.
#
# ### Neu phien bi danh dau **failed**
#
# Kaggle **khong luu output** cua version bi giet vi qua gio, nen "Add Data ->
# Your Work" se khong thay no. Van lay lai duoc:
#
# 1. Mo version bi failed -> tab **Output** -> tai `last.pt` ve.
#    Trinh duyet doi duoi thanh `.zip` (file `.pt` cua PyTorch von la mot zip).
#    **Doi ten lai thanh `.pt`, KHONG giai nen.**
# 2. Upload thanh Kaggle dataset.
# 3. **Add Data** dataset do, roi dien duong dan file vao `MANUAL_LAST` o cell 2:
#
# ```python
# MANUAL_LAST = {
#     BASE_NAME: "/kaggle/input/vd-resume/last.pt",
#     OURS_NAME: "",
# }
# ```
#
# Neu ban upload ca thu muc (giu nguyen ten `vd_yolo26m/weights/last.pt`) thi
# khong can dien gi — cell resume tu tim thay.
#
# Repo: https://github.com/xauskeleton/yolo26_prune_cwd

# %% [markdown]
# ## 1. Setup

# %%
import os, sys, glob, shutil, pathlib, subprocess

REPO_DIR = pathlib.Path("/kaggle/working/yolo")
if not REPO_DIR.exists():
    subprocess.run(["git", "clone", "--depth", "1",
                    "https://github.com/xauskeleton/yolo26_prune_cwd", str(REPO_DIR)], check=True)
os.chdir(REPO_DIR)

# Phai dung fork nay, KHONG "pip install ultralytics": checkpoint sau khi prune
# duoc pickle voi ultralytics.nn.tasks_pruned nen ban chinh thuc khong load duoc.
sys.path.insert(0, str(REPO_DIR))
sys.path.insert(0, str(REPO_DIR / "pruning"))
# DDP sinh tien trinh con chay file tam ngoai repo -> phai truyen qua PYTHONPATH.
os.environ["PYTHONPATH"] = str(REPO_DIR)

subprocess.run([sys.executable, "-m", "pip", "install", "-q",
                "-r", "requirements.txt"], check=False)
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-e", ".",
                "--no-deps"], check=False)

import torch
from ultralytics import YOLO
print("GPU:", torch.cuda.device_count())
# Out:
# Cloning into '/kaggle/working/yolo'...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.6/766.6 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 94.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 74.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 34.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 33.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 54.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 63.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 78.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.10.0+cu128 requires torch==2.10.0, but you have torch 2.6.0 which is incompatible.
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# GPU: 2

# %% [markdown]
# ## 2. Cau hinh

# %%
SIZE   = "n"
MODEL  = "yolo26n.pt"
RATIO  = 0.5

DATA   = "VisDrone.yaml"   # Ultralytics tu tai 2.3 GB, can Internet: On
EPOCHS = 100
BATCH  = 16
IMGSZ  = 640
DEVICE = "0,1" if torch.cuda.device_count() > 1 else "0"
STOP_AFTER_H = 10.0        # tu dung truoc moc 12h de output kip luu

# Chot cung ba tham so nay thay vi de mac dinh, vi cac run VOC truoc day KHONG
# dong nhat: n/s/l chay batch 32 + cos_lr=True + patience 20-30, con m chay
# batch 16 + cos_lr=False + patience 100. Bang theo size ma moi size mot config
# thi khong so sanh duoc. Lay config cua m vi do la cau hinh chinh cua bai.
# patience=100 = tat early stop -> ca 4 size deu la run 100 epoch that.
COS_LR   = False
PATIENCE = 100
WARMUP   = 3.0

BASE_NAME = "vd_yolo26n"
OURS_NAME = "vd_oursn"
PRUNED = REPO_DIR / "weights" / "yolo26n_vd_pruned50.pt"

# Chi dung khi phien bi Kaggle danh dau FAILED: version do khong tu luu output
# nen "Add Data -> Your Work" se khong co no. Vao tab Output cua version do,
# tai last.pt ve (trinh duyet doi duoi thanh .zip - **doi ten lai thanh .pt**,
# KHONG giai nen), upload thanh dataset roi dan duong dan file vao day.
MANUAL_LAST = {
    BASE_NAME: "",   # vd "/kaggle/input/vd-resume/last.pt"
    OURS_NAME: "",
}

print(BASE_NAME, "|", OURS_NAME, "|", DEVICE)
# Out:
# vd_yolo26n | vd_oursn | 0,1

# %% [markdown]
# ## 3. Ham dung chung

# %%
# Hai ham nho dung chung cho ca hai lan train duoi day.

def epochs_of(run_dir):
    """So epoch da train xong cua mot thu muc run.

    Doc results.csv truoc; neu khong co (vd chi tai moi last.pt ve tu mot phien
    bi Kaggle danh dau failed) thi doc thang so epoch trong checkpoint.
    """
    run_dir = pathlib.Path(run_dir)
    csv = run_dir / "results.csv"
    if csv.exists():
        rows = [r for r in csv.read_text().strip().splitlines()[1:] if r.strip()]
        if rows:
            return int(float(rows[-1].split(",")[0]))
    last = run_dir / "weights" / "last.pt"
    if last.exists():
        try:
            ck = torch.load(last, map_location="cpu", weights_only=False)
            ep = int(ck.get("epoch", -1))
            total = int((ck.get("train_args") or {}).get("epochs", 0) or 0)
            del ck
            return (ep + 1) if ep >= 0 else total
        except Exception:
            pass
    return 0


def done_epochs(name):
    return epochs_of(REPO_DIR / "runs" / name)


def train(name, weights, **extra):
    """Train moi, hoac train TIEP neu phien truoc bi cat ngang.

    Co last.pt la resume. Khong lay so epoch lam dieu kien: doc that bai thi se
    am tham train lai tu dau, mat ca chuc gio ma khong bao gi.
    """
    last = REPO_DIR / "runs" / name / "weights" / "last.pt"
    if last.exists():
        print("[{}] resume tu epoch {}".format(name, done_epochs(name)))
        YOLO(str(last)).train(resume=True, stop_after_h=STOP_AFTER_H)
    else:
        print("[{}] train tu dau".format(name))
        YOLO(weights).train(data=DATA, epochs=EPOCHS, batch=BATCH, imgsz=IMGSZ,
                            device=DEVICE, seed=0,
                            cos_lr=COS_LR, patience=PATIENCE,
                            warmup_epochs=WARMUP,
                            project=str(REPO_DIR / "runs"), name=name,
                            exist_ok=True, stop_after_h=STOP_AFTER_H, **extra)
    return done_epochs(name)

# %% [markdown]
# ## 4. Resume

# %%
# Kaggle giet phien o 12h, va phien BI GIET thi khong luu output -> mat sach
# last.pt. Vi the moi phien tu dung o STOP_AFTER_H roi ket thuc binh thuong.
# Lan sau: Add Data -> Your Work -> output lan truoc, cell nay chep runs/ ve.
def bring_back(name):
    """Tim checkpoint cu trong /kaggle/input va chep ve runs/<name>."""
    dst = REPO_DIR / "runs" / name
    if dst.exists():
        return

    cands = []
    # (a) Add Data output cua lan chay truoc: .../yolo/runs/<name>/
    cands += glob.glob("/kaggle/input/**/runs/" + name, recursive=True)
    # (b) Upload thu cong: thu muc ten <name> nam bat ky dau, khong can co runs/.
    cands += glob.glob("/kaggle/input/**/" + name, recursive=True)
    cands = [c for c in set(cands)
             if pathlib.Path(c, "weights", "last.pt").exists()]

    if cands:
        # Gan nhieu output (phien 1, phien 2, ...) thi phai lay ban NHIEU EPOCH
        # NHAT. Lay "cai dau tien tim thay" la sai: thu tu glob khong xac dinh,
        # co the chep nham ban cu va mat vai gio train ma khong he biet.
        best = max(cands, key=epochs_of)
        shutil.copytree(best, dst)
        print("  {}: {} epoch  <- {}".format(name, epochs_of(best), best))
        return

    # (c) Chi co moi file last.pt roi le -> dan duong dan vao MANUAL_LAST.
    man = MANUAL_LAST.get(name, "")
    if man and pathlib.Path(man).exists():
        (dst / "weights").mkdir(parents=True, exist_ok=True)
        shutil.copy2(man, dst / "weights" / "last.pt")
        print("  {}: {} epoch  <- (thu cong) {}".format(name, epochs_of(dst), man))
    elif man:
        print("  {}: !! MANUAL_LAST tro toi file khong ton tai: {}".format(name, man))


for name in (BASE_NAME, OURS_NAME):
    bring_back(name)

# Model da prune cung chep ve, neu khong se prune lai (khong sai, chi ton them).
if not PRUNED.exists():
    for src in glob.glob("/kaggle/input/**/" + PRUNED.name, recursive=True):
        PRUNED.parent.mkdir(parents=True, exist_ok=True)
        shutil.copy2(src, PRUNED)
        print("  {} <- {}".format(PRUNED.name, src))
        break

print()
print("baseline:", done_epochs(BASE_NAME), "/", EPOCHS, "epoch")
print("ours    :", done_epochs(OURS_NAME), "/", EPOCHS, "epoch")
# Out:
# baseline: 0 / 100 epoch
# ours    : 0 / 100 epoch

# %% [markdown]
# ## 5. Baseline yolo26n

# %%
n_base = train(BASE_NAME, MODEL)

if n_base < EPOCHS:
    print()
    print("Baseline moi {}/{} epoch - het gio phien nay.".format(n_base, EPOCHS))
    print("Add Data output lan nay roi Save & Run All lai. Cac cell duoi se bo qua.")
# Out:
# [vd_yolo26n] train tu dau
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 123.5MB/s 0.0s
# New https://pypi.org/project/ultralytics/8.4.163 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.14 🚀 Python-3.12.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 14912MiB)
#                                                       CUDA:1 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, cwd_learnable_tau_init=9.0, cwd_learnable_tau_lr=0.001, cwd_projection=False, cwd_tau_reg=0.1, cwd_temperature=9.0, data=VisDrone.yaml, degrees=0.0, deterministic=True, device=0,1, dfl=1.5, dms=False, dms_decay_ratio=1, dms_grad_scale=-1.0, dms_lambda=1.0, dms_lr=2e-05, dms_target=0.3, dms_taylor_type=taylor, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, finetune=False, fitnets_normalize=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, kd=False, kd_lambda=0.5, kd_layers=neck, kd_method=cwd, kd_teacher=None, kd_warmup=5, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mgd_mask_ratio=0.5, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=vd_yolo26n, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/yolo/runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/yolo/runs/vd_yolo26n, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, sr=None, stop_after_h=10.0, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
# WARNING ⚠️ Dataset 'VisDrone.yaml' images not found, missing path '/kaggle/working/datasets/VisDrone/images/val'
# Downloading 3 file(s) with 4 threads to /kaggle/working/datasets/VisDrone...
# Downloading https://ultralytics.com/assets/VisDrone2019-DET-val.zip to '/kaggle/working/datasets/VisDrone/VisDrone2019-DET-val.zip': 100% ━━━━━━━━━━━━ 77.9MB 98.1MB/s 0.8s
# Unzipping /kaggle/working/datasets/VisDrone/VisDrone2019-DET-val.zip to /kaggle/working/datasets/VisDrone/VisDrone2019-DET-val...: 100% ━━━━━━━━━━━━ 1099/1099 2.1Kfiles/s 0.5s
# Downloading https://ultralytics.com/assets/VisDrone2019-DET-test-dev.zip to '/kaggle/working/datasets/VisDrone/VisDrone2019-DET-test-dev.zip': 100% ━━━━━━━━━━━━ 296.8MB 89.0MB/s 3.3s
# Unzipping /kaggle/working/datasets/VisDrone/VisDrone2019-DET-test-dev.zip to /kaggle/working/datasets/VisDrone/VisDrone2019-DET-test-dev...: 100% ━━━━━━━━━━━━ 3223/3223 1.7Kfiles/s 1.9s
# Downloading https://ultralytics.com/assets/VisDrone2019-DET-train.zip to '/kaggle/working/datasets/VisDrone/VisDrone2019-DET-train.zip': 100% ━━━━━━━━━━━━ 1.4GB 88.2MB/s 16.8s
# Unzipping /kaggle/working/datasets/VisDrone/VisDrone2019-DET-train.zip to /kaggle/working/datasets/VisDrone/VisDrone2019-DET-train...: 100% ━━━━━━━━━━━━ 12945/12945 2.1Kfiles/s 6.1s
# Converting train: ━━━━━━━━━━━━ 6471 2.3Kit/s 2.8s
# Converting val: ━━━━━━━━━━━━ 548 1.3Kit/s 0.3s
# Converting test: ━━━━━━━━━━━━ 1610 2.0Kit/s 0.7s
# Dataset download success ✅ (27.8s), saved to /kaggle/working/datasets
#
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 40.4MB/s 0.0s
# Overriding model.yaml nc=80 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    245076  ultralytics.nn.modules.head.Detect           [10, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,507,700 parameters, 2,507,700 gradients, 5.8 GFLOPs
#
# Transferred 606/708 items from pretrained weights
# DDP: debug command /usr/bin/python3 -m torch.distributed.run --nproc_per_node 2 --master_port 56203 /root/.config/Ultralytics/DDP/_temp_eukq8iz7140108006395248.py
# Ultralytics 8.4.14 🚀 Python-3.12.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 14912MiB)
#                                                       CUDA:1 (Tesla T4, 14912MiB)
# Overriding model.yaml nc=80 with nc=10
# Transferred 606/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2242.2±1038.6 MB/s, size: 206.8 KB)
# train: Scanning /kaggle/working/datasets/VisDrone/labels/train... 6471 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6471/6471 1.1Kit/s 5.8s
# train: /kaggle/working/datasets/VisDrone/images/train/0000137_02220_d_0000163.jpg: 1 duplicate labels removed
# train: /kaggle/working/datasets/VisDrone/images/train/0000140_00118_d_0000002.jpg: 1 duplicate labels removed
# train: /kaggle/working/datasets/VisDrone/images/train/9999945_00000_d_0000114.jpg: 1 duplicate labels removed
# train: /kaggle/working/datasets/VisDrone/images/train/9999987_00000_d_0000049.jpg: 1 duplicate labels removed
# train: New cache created: /kaggle/working/datasets/VisDrone/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1607.5±1307.0 MB/s, size: 136.5 KB)
# val: Scanning /kaggle/working/datasets/VisDrone/labels/val... 548 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 548/548 1.0Kit/s 0.5s
# val: New cache created: /kaggle/working/datasets/VisDrone/labels/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.01, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to /kaggle/working/yolo/runs/vd_yolo26n/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/yolo/runs/vd_yolo26n
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100       3.7G      2.478      3.161   0.003799        360        640: 100% ━━━━━━━━━━━━ 405/405 1.8it/s 3:40
# /kaggle/working/yolo/ultralytics/utils/metrics.py:75: UserWarning: Specified kernel cache directory could not be created! This disables kernel caching. Specified directory is /root/.cache/torch/kernels. This warning will appear only once per process. (Triggered internally at /pytorch/aten/src/ATen/native/cuda/jit_utils.cpp:1442.)
#   inter = (torch.min(a2, b2) - torch.max(a1, b1)).clamp_(0).prod(2)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.5it/s 4.0s
#                    all        548      38759      0.294      0.156      0.115     0.0598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      3.71G      2.399      2.161   0.003341        351        640: 100% ━━━━━━━━━━━━ 405/405 2.4it/s 2:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 6.0it/s 3.0s
#                    all        548      38759      0.293      0.197      0.168     0.0919
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      3.73G      2.408      2.014   0.003302        278        640: 100% ━━━━━━━━━━━━ 405/405 2.7it/s 2:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.8it/s 3.1s
#                    all        548      38759      0.375       0.22      0.188      0.101
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      3.74G      2.391      1.908   0.003259        384        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.7it/s 3.1s
#                    all        548      38759      0.314      0.242       0.21       0.11
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      3.75G      2.344      1.818   0.003228        406        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.1s
#                    all        548      38759      0.326      0.251      0.226      0.122
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      3.77G      2.344      1.786   0.003157        371        640: 100% ━━━━━━━━━━━━ 405/405 2.9it/s 2:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.1s
#                    all        548      38759      0.355      0.251      0.237       0.13
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      3.79G      2.314      1.734   0.003093        349        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.0s
#                    all        548      38759      0.345      0.258      0.244      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100       3.8G      2.292      1.701   0.003063        432        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.7it/s 3.2s
#                    all        548      38759      0.337      0.274      0.249      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      4.64G      2.292      1.693   0.003066        392        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.8it/s 3.1s
#                    all        548      38759      0.356      0.271      0.255      0.139
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      4.67G       2.28      1.675   0.003026        189        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.1s
#                    all        548      38759      0.337      0.267       0.25      0.137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      4.68G      2.272      1.663   0.003003        280        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.6it/s 3.2s
#                    all        548      38759      0.374      0.273      0.263      0.145
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100       4.7G      2.261      1.644   0.002984        192        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.7it/s 3.1s
#                    all        548      38759      0.357      0.277       0.26      0.142
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100       4.7G      2.263      1.635   0.002974        208        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.8it/s 3.1s
#                    all        548      38759      0.367      0.284      0.264      0.143
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      4.72G      2.236      1.625   0.002953        111        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.8it/s 3.1s
#                    all        548      38759      0.358      0.281      0.267      0.148
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      4.74G      2.234      1.603   0.002928        256        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 6.0it/s 3.0s
#                    all        548      38759      0.374      0.287      0.275       0.15
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      4.75G      2.228      1.605   0.002921        247        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.8it/s 3.1s
#                    all        548      38759      0.383      0.303      0.287      0.158
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      4.76G      2.218      1.592   0.002891        312        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.8it/s 3.1s
#                    all        548      38759      0.385      0.298      0.286      0.157
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      4.78G      2.198       1.58   0.002893        345        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.8it/s 3.1s
#                    all        548      38759      0.388      0.285      0.276      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      4.79G      2.217      1.571   0.002878        260        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.1s
#                    all        548      38759      0.402      0.295      0.293      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      4.81G      2.207      1.565   0.002869        220        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.0s
#                    all        548      38759      0.411      0.304      0.296      0.164
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      4.82G      2.207      1.567   0.002866        391        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.8it/s 3.1s
#                    all        548      38759      0.404      0.295      0.292      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      4.84G       2.21      1.564   0.002856        197        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.0s
#                    all        548      38759      0.409      0.299      0.294      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      4.85G      2.173       1.53   0.002829        400        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.1s
#                    all        548      38759      0.393      0.306      0.293      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      4.87G      2.191       1.54   0.002792        531        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.8it/s 3.1s
#                    all        548      38759      0.393      0.311      0.296      0.163
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      4.87G       2.16      1.519   0.002825        282        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.6it/s 3.2s
#                    all        548      38759      0.413      0.307      0.302      0.166
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      4.89G      2.187      1.537   0.002813        294        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 6.0it/s 3.0s
#                    all        548      38759      0.407      0.306        0.3      0.163
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      4.91G      2.172      1.528   0.002793        307        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.8it/s 3.1s
#                    all        548      38759      0.425       0.31      0.309      0.171
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      4
# Results saved to /kaggle/working/yolo/runs/vd_yolo26n

# %% [markdown]
# ## 6. Prune 50%

# %%
# Goi thang cac ham trong pruning/, khong qua script.
from prune_common import load_and_prepare, create_masks, finalize_pruning
from prune_l1norm import compute_l1norm_importance

BEST_BASE = REPO_DIR / "runs" / BASE_NAME / "weights" / "best.pt"

if n_base < EPOCHS:
    print("Bo qua: baseline chua xong.")
elif PRUNED.exists():
    print("Da co", PRUNED.name)
else:
    PRUNED.parent.mkdir(parents=True, exist_ok=True)
    m0, bn_dict, ignore_bn, _chunk, layer_cfg, pruned_yaml = load_and_prepare(
        str(BEST_BASE), str(REPO_DIR / "cfg" / "yolo26m.yaml"), SIZE, None)
    imp = compute_l1norm_importance(m0, bn_dict, ignore_bn)
    masks = create_masks(imp, m0, ignore_bn, layer_cfg, RATIO, 8)
    out = finalize_pruning(m0, masks, pruned_yaml, ignore_bn, str(BEST_BASE),
                           str(REPO_DIR / "weights"), 8, RATIO,
                           method_name="l1norm")
    pathlib.Path(out).replace(PRUNED)
    print("->", PRUNED)
# Out:
# Step 1: Thu thập BatchNorm layers...
#   Tổng BN layers: 114
#   Ignore (residual): 32
#   Chunk constraint: 0
#   Prunable BN layers: 82
#
# Step 6: Tạo pruned model config...
#   nc: 10, scale: n
#   Backbone layers: 11
#   Head layers: 13
#     [ 0] n=1 Conv                 args=[64, 3, 2]
#     [ 1] n=1 Conv                 args=[128, 3, 2]
#     [ 2] n=1 C3k2PrunedBn         args=[256, False]
#     [ 3] n=1 Conv                 args=[256, 3, 2]
#     [ 4] n=1 C3k2PrunedBn         args=[512, False]
#     [ 5] n=1 Conv                 args=[512, 3, 2]
#     [ 6] n=1 C3k2Pruned           args=[512, True]
#     [ 7] n=1 Conv                 args=[1024, 3, 2]
#     [ 8] n=1 C3k2Pruned           args=[1024, True]
#     [ 9] n=1 SPPFPruned           args=[1024, 5, 3, True]
#     [10] n=1 C2PSAPruned          args=[1024]
#     [11] n=1 nn.Upsample          args=['None', 2, 'nearest']
#     [12] n=1 Concat               args=[1]
#     [13] n=1 C3k2Pruned           args=[512, True]
#     [14] n=1 nn.Upsample          args=['None', 2, 'nearest']
#     [15] n=1 Concat               args=[1]
#     [16] n=1 C3k2Pruned           args=[256, True]
#     [17] n=1 Conv                 args=[256, 3, 2]
#     [18] n=1 Concat               args=[1]
#     [19] n=1 C3k2Pruned           args=[512, True]
#     [20] n=1 Conv                 args=[512, 3, 2]
#     [21] n=1 Concat               args=[1]
#     [22] n=1 C3k2PrunedAttn       args=[1024, True]
#     [23] n=1 DetectPruned         args=[10]
#   L1 Norm importance computed for 82 layers
#
# Step 7: Tạo pruning masks (divisor=8)...
# ==============================================================================================================
# Layer name                          | Origin |  Ratio |    Raw | Rounded | Sparsity | Note
# ==============================================================================================================
# model.0.bn                          |     16 |   0.50 |     16 |      16 |    0.000 |
# model.1.bn                          |     32 |   0.50 |     16 |      16 |    0.500 |
# model.2.cv1.bn                      |     32 |      - |      - |       - |        - | SKIP (residual)
# model.2.cv2.bn                      |     64 |   0.50 |     31 |      32 |    0.500 |
# model.2.m.0.cv1.bn                  |      8 |   0.50 |      8 |       8 |    0.000 |
# model.2.m.0.cv2.bn                  |     16 |      - |      - |       - |        - | SKIP (residual)
# model.3.bn                          |     64 |   0.50 |     31 |      32 |    0.500 |
# model.4.cv1.bn                      |     64 |      - |      - |       - |        - | SKIP (residual)
# model.4.cv2.bn                      |    128 |   0.50 |     63 |      64 |    0.500 |
# model.4.m.0.cv1.bn                  |     16 |   0.50 |     16 |      16 |    0.000 |
# model.4.m.0.cv2.bn                  |     32 |      - |      - |       - |        - | SKIP (residual)
# model.5.bn                          |    128 |   0.50 |     63 |      64 |    0.500 |
# model.6.cv1.bn                      |    128 |   0.50 |     63 |      64 |    0.500 |
# model.6.cv2.bn                      |    128 |   0.50 |     63 |      64 |    0.500 |
# model.6.m.0.cv1.bn                  |     32 |      - |      - |       - |        - | SKIP (residual)
# model.6.m.0.cv2.bn                  |     32 |   0.50 |     16 |      16 |    0.500 |
# model.6.m.0.cv3.bn                  |     64 |   0.50 |     31 |      32 |    0.500 |
# model.6.m.0.m.0.cv1.bn              |     32 |   0.50 |     16 |      16 |    0.500 |
# model.6.m.0.m.0.cv2.bn              |     32 |      - |      - |       - |        - | SKIP (residual)
# model.6.m.0.m.1.cv1.bn              |     32 |   0.50 |     16 |      16 |    0.500 |
# model.6.m.0.m.1.cv2.bn              |     32 |      - |      - |       - |        - | SKIP (residual)
# model.7.bn                          |    256 |   0.50 |    127 |     128 |    0.500 |
# model.8.cv1.bn                      |    256 |   0.50 |    127 |     128 |    0.500 |
# model.8.cv2.bn                      |    256 |   0.50 |    127 |     128 |    0.500 |
# model.8.m.0.cv1.bn                  |     64 |      - |      - |       - |        - | SKIP (residual)
# model.8.m.0.cv2.bn                  |     64 |   0.50 |     31 |      32 |    0.500 |
# model.8.m.0.cv3.bn                  |    128 |   0.50 |     63 |      64 |    0.500 |
# model.8.m.0.m.0.cv1.bn              |     64 |   0.50 |     31 |      32 |    0.500 |
# model.8.m.0.m.0.cv2.bn              |     64 |      - |      - |       - |        - | SKIP (residual)
# model.8.m.0.m.1.cv1.bn              |     64 |   0.50 |     31 |      32 |    0.500 |
# model.8.m.0.m.1.cv2.bn              |     64 |      - |      - |       - |        - | SKIP (residual)
# model.9.cv1.bn                      |    128 |   0.50 |     63 |      64 |    0.500 |
# model.9.cv2.bn                      |    256 |   0.50 |    127 |     128 |    0.500 |
# model.10.cv1.bn                     |    256 |      - |      - |       - |        - | SKIP (residual)
# model.10.cv2.bn                     |    256 |   0.50 |    127 |     128 |    0.500 |
# model.10.m.0.attn.qkv.bn            |    256 |      - |      - |       - |        - | SKIP (residual)
# model.10.m.0.attn.proj.bn           |    128 |      - |      - |       - |        - | SKIP (residual)
# model.10.m.0.attn.pe.bn             |    128 |      - |      - |       - |        - | SKIP (residual)
# model.10.m.0.ffn.0.bn               |    256 |      - |      - |       - |        - | SKIP (residual)
# model.10.m.0.ffn.1.bn               |    128 |      - |      - |       - |        - | SKIP (residual)
# model.13.cv1.bn                     |    128 |   0.50 |     63 |      64 |    0.500 |
# model.13.cv2.bn                     |    128 |   0.50 |     63 |      64 |    0.500 |
# model.13.m.0.cv1.bn                 |     32 |      - |      - |       - |        - | SKIP (residual)
# model.13.m.0.cv2.bn                 |     32 |   0.50 |     16 |      16 |    0.500 |
# model.13.m.0.cv3.bn                 |     64 |   0.50 |     31 |      32 |    0.500 |
# model.13.m.0.m.0.cv1.bn             |     32 |   0.50 |     16 |      16 |    0.500 |
# model.13.m.0.m.0.cv2.bn             |     32 |      - |      - |       - |        - | SKIP (residual)
# model.13.m.0.m.1.cv1.bn             |     32 |   0.50 |     16 |      16 |    0.500 |
# model.13.m.0.m.1.cv2.bn             |     32 |      - |      - |       - |        - | SKIP (residual)
# model.16.cv1.bn                     |     64 |   0.50 |     31 |      32 |    0.500 |
# model.16.cv2.bn                     |     64 |   0.50 |     31 |      32 |    0.500 |
# model.16.m.0.cv1.bn                 |     16 |      - |      - |       - |        - | SKIP (residual)
# model.16.m.0.cv2.bn                 |     16 |   0.50 |     16 |      16 |    0.000 |
# model.16.m.0.cv3.bn                 |     32 |   0.50 |     16 |      16 |    0.500 |
# model.16.m.0.m.0.cv1.bn             |     16 |   0.50 |     16 |      16 |    0.000 |
# model.16.m.0.m.0.cv2.bn             |     16 |      - |      - |       - |        - | SKIP (residual)
# model.16.m.0.m.1.cv1.bn             |     16 |   0.50 |     16 |      16 |    0.000 |
# model.16.m.0.m.1.cv2.bn             |     16 |      - |      - |       - |        - | SKIP (residual)
# model.17.bn                         |     64 |   0.50 |     31 |      32 |    0.500 |
# model.19.cv1.bn                     |    128 |   0.50 |     63 |      64 |    0.500 |
# model.19.cv2.bn                     |    128 |   0.50 |     63 |      64 |    0.500 |
# model.19.m.0.cv1.bn                 |     32 |      - |      - |       - |        - | SKIP (residual)
# model.19.m.0.cv2.bn                 |     32 |   0.50 |     16 |      16 |    0.500 |
# model.19.m.0.cv3.bn                 |     64 |   0.50 |     31 |      32 |    0.500 |
# model.19.m.0.m.0.cv1.bn             |     32 |   0.50 |     16 |      16 |    0.500 |
# model.19.m.0.m.0.cv2.bn             |     32 |      - |      - |       - |        - | SKIP (residual)
# model.19.m.0.m.1.cv1.bn             |     32 |   0.50 |     16 |      16 |    0.500 |
# model.19.m.0.m.1.cv2.bn             |     32 |      - |      - |       - |        - | SKIP (residual)
# model.20.bn                         |    128 |   0.50 |     63 |      64 |    0.500 |
# model.22.cv1.bn                     |    256 |      - |      - |       - |        - | SKIP (residual)
# model.22.cv2.bn                     |    256 |   0.50 |    127 |     128 |    0.500 |
# model.22.m.0.0.cv1.bn               |     64 |   0.50 |     31 |      32 |    0.500 |
# model.22.m.0.0.cv2.bn               |    128 |      - |      - |       - |        - | SKIP (residual)
# model.22.m.0.1.attn.qkv.bn          |    256 |      - |      - |       - |        - | SKIP (residual)
# model.22.m.0.1.attn.proj.bn         |    128 |      - |      - |       - |        - | SKIP (residual)
# model.22.m.0.1.attn.pe.bn           |    128 |      - |      - |       - |        - | SKIP (residual)
# model.22.m.0.1.ffn.0.bn             |    256 |      - |      - |       - |        - | SKIP (residual)
# model.22.m.0.1.ffn.1.bn             |    128 |      - |      - |       - |        - | SKIP (residual)
# model.23.cv2.0.0.bn                 |     16 |   0.50 |     16 |      16 |    0.000 |
# model.23.cv2.0.1.bn                 |     16 |   0.50 |     16 |      16 |    0.000 |
# model.23.cv2.1.0.bn                 |     16 |   0.50 |     16 |      16 |    0.000 |
# model.23.cv2.1.1.bn                 |     16 |   0.50 |     16 |      16 |    0.000 |
# model.23.cv2.2.0.bn                 |     16 |   0.50 |     16 |      16 |    0.000 |
# model.23.cv2.2.1.bn                 |     16 |   0.50 |     16 |      16 |    0.000 |
# model.23.cv3.0.0.0.bn               |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.cv3.0.0.1.bn               |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.cv3.0.1.0.bn               |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.cv3.0.1.1.bn               |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.cv3.1.0.0.bn               |    128 |   0.50 |     63 |      64 |    0.500 |
# model.23.cv3.1.0.1.bn               |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.cv3.1.1.0.bn               |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.cv3.1.1.1.bn               |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.cv3.2.0.0.bn               |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.cv3.2.0.1.bn               |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.cv3.2.1.0.bn               |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.cv3.2.1.1.bn               |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.one2one_cv2.0.0.bn         |     16 |   0.50 |     16 |      16 |    0.000 |
# model.23.one2one_cv2.0.1.bn         |     16 |   0.50 |     16 |      16 |    0.000 |
# model.23.one2one_cv2.1.0.bn         |     16 |   0.50 |     16 |      16 |    0.000 |
# model.23.one2one_cv2.1.1.bn         |     16 |   0.50 |     16 |      16 |    0.000 |
# model.23.one2one_cv2.2.0.bn         |     16 |   0.50 |     16 |      16 |    0.000 |
# model.23.one2one_cv2.2.1.bn         |     16 |   0.50 |     16 |      16 |    0.000 |
# model.23.one2one_cv3.0.0.0.bn       |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.one2one_cv3.0.0.1.bn       |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.one2one_cv3.0.1.0.bn       |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.one2one_cv3.0.1.1.bn       |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.one2one_cv3.1.0.0.bn       |    128 |   0.50 |     63 |      64 |    0.500 |
# model.23.one2one_cv3.1.0.1.bn       |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.one2one_cv3.1.1.0.bn       |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.one2one_cv3.1.1.1.bn       |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.one2one_cv3.2.0.0.bn       |    256 |   0.50 |    127 |     128 |    0.500 |
# model.23.one2one_cv3.2.0.1.bn       |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.one2one_cv3.2.1.0.bn       |     64 |   0.50 |     31 |      32 |    0.500 |
# model.23.one2one_cv3.2.1.1.bn       |     64 |   0.50 |     31 |      32 |    0.500 |
# ==============================================================================================================
#
# Step 8: Validate divisibility...
#   ✅ Tất cả layers đều chia hết cho 8!
#
# Step 9: Build pruned model...
#
#                    from  n    params  module                                            arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv                  [3, 16, 3, 2]
#   1                  -1  1      2336  ultralytics.nn.modules.conv.Conv                  [16, 16, 3, 2]
#   2                  -1  1      4528  ultralytics.nn.modules.block_pruned.C3k2PrunedBn  [16, 32, [16, 16], [8], 32, 1]
#   3                  -1  1      9280  ultralytics.nn.modules.conv.Conv                  [32, 32, 3, 2]
#   4                  -1  1     17760  ultralytics.nn.modules.block_pruned.C3k2PrunedBn  [32, 64, [32, 32], [16], 64, 1]
#   5                  -1  1     36992  ultralytics.nn.modules.conv.Conv                  [64, 64, 3, 2]
#   6                  -1  1     32880  ultralytics.nn.modules.block_pruned.C3k2Pruned    [64, 64, [21, 43], [32], [16], [32], [[16, 16]], [[32, 32]], [2], 64, 1, 2, True]
#   7                  -1  1     73984  ultralytics.nn.modules.conv.Conv                  [64, 128, 3, 2]
#   8                  -1  1    130112  ultralytics.nn.modules.block_pruned.C3k2Pruned    [128, 128, [44, 84], [64], [32], [64], [[32, 32]], [[64, 64]], [2], 128, 1, 2, True]
#   9                  -1  1     41344  ultralytics.nn.modules.block_pruned.SPPFPruned    [128, 64, 128, 5, 3, True]
#  10                  -1  1    183936  ultralytics.nn.modules.block_pruned.C2PSAPruned   [128, 256, [128, 128], 128, 1, 0.5]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample              [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat                [1]
#  13                  -1  1     40736  ultralytics.nn.modules.block_pruned.C3k2Pruned    [192, 64, [28, 36], [32], [16], [32], [[16, 16]], [[32, 32]], [2], 64, 1, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample              [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat                [1]
#  16                  -1  1     16608  ultralytics.nn.modules.block_pruned.C3k2Pruned    [128, 32, [4, 28], [16], [16], [16], [[16, 16]], [[16, 16]], [2], 32, 1, 2, True]
#  17                  -1  1      9280  ultralytics.nn.modules.conv.Conv                  [32, 32, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat                [1]
#  19                  -1  1     34304  ultralytics.nn.modules.block_pruned.C3k2Pruned    [96, 64, [34, 30], [32], [16], [32], [[16, 16]], [[32, 32]], [2], 64, 1, 2, True]
#  20                  -1  1     36992  ultralytics.nn.modules.conv.Conv                  [64, 64, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat                [1]
#  22                  -1  1    290752  ultralytics.nn.modules.block_pruned.C3k2PrunedAttn[192, 256, [128, 128], 1, [32], 128, True]
#  23        [16, 19, 22]  1    109396  ultralytics.nn.modules.head_pruned.DetectPruned   [[16, 16, 16], [16, 16, 16], [32, 64, 128], [32, 32, 32], [32, 32, 32], [32, 32, 32], [16, 16, 16], [16, 16, 16], [32, 64, 128], [32, 32, 32], [32, 32, 32], [32, 32, 32], 10, 1, (32, 64, 128)]
# Model summary: 258 layers, 1,071,684 parameters, 1,071,684 gradients, 2.6 GFLOPs
#
#
# Step 10: Copy weights từ original model...
#    Copy weights hoàn tất!
#
# Step 11: Save pruned model...
#    Model saved: /kaggle/working/yolo/weights/best_l1norm_div8.pt
#
# Testing forward pass...
#    Forward pass successful!
#
# ====================================================================================================
#  PRUNING SUMMARY (l1norm)
# ====================================================================================================
# Method:            l1norm
# Divisor:           8
# Prune ratio:       0.500
# Total channels:    9,496 → 6,440
# Compression:       1.47x
# Model saved:       /kaggle/working/yolo/weights/best_l1norm_div8.pt
# ====================================================================================================
#
#  PRUNING HOÀN TẤT!
#
# -> /kaggle/working/yolo/weights/yolo26n_vd_pruned50.pt

# %% [markdown]
# ## 7. Finetune + CWD

# %%
if n_base < EPOCHS or not PRUNED.exists():
    print("Bo qua: chua co model da prune.")
    n_ours = 0
else:
    # Teacher la baseline cua chinh size nay.
    n_ours = train(OURS_NAME, str(PRUNED),
                   finetune=True,          # build DetectionModelPruned tu maskbndict
                   kd=True, kd_teacher=str(BEST_BASE), kd_method="cwd",
                   kd_lambda=0.5, kd_layers="neck", kd_warmup=5,
                   cwd_temperature=9.0)
    if n_ours < EPOCHS:
        print()
        print("Ours moi {}/{} epoch - Add Data output lan nay roi chay lai."
              .format(n_ours, EPOCHS))
# Out:
# [vd_oursn] train tu dau
# New https://pypi.org/project/ultralytics/8.4.163 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.14 🚀 Python-3.12.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 14912MiB)
#                                                       CUDA:1 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, cwd_learnable_tau_init=9.0, cwd_learnable_tau_lr=0.001, cwd_projection=False, cwd_tau_reg=0.1, cwd_temperature=9.0, data=VisDrone.yaml, degrees=0.0, deterministic=True, device=0,1, dfl=1.5, dms=False, dms_decay_ratio=1, dms_grad_scale=-1.0, dms_lambda=1.0, dms_lr=2e-05, dms_target=0.3, dms_taylor_type=taylor, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, finetune=True, fitnets_normalize=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, kd=True, kd_lambda=0.5, kd_layers=neck, kd_method=cwd, kd_teacher=/kaggle/working/yolo/runs/vd_yolo26n/weights/best.pt, kd_warmup=5, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mgd_mask_ratio=0.5, mixup=0.0, mode=train, model=/kaggle/working/yolo/weights/yolo26n_vd_pruned50.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=vd_oursn, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/yolo/runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/yolo/runs/vd_oursn, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, sr=None, stop_after_h=10.0, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Finetune mode: building DetectionModelPruned with maskbndict
#
#                    from  n    params  module                                            arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv                  [3, 16, 3, 2]
#   1                  -1  1      2336  ultralytics.nn.modules.conv.Conv                  [16, 16, 3, 2]
#   2                  -1  1      4528  ultralytics.nn.modules.block_pruned.C3k2PrunedBn  [16, 32, [16, 16], [8], 32, 1]
#   3                  -1  1      9280  ultralytics.nn.modules.conv.Conv                  [32, 32, 3, 2]
#   4                  -1  1     17760  ultralytics.nn.modules.block_pruned.C3k2PrunedBn  [32, 64, [32, 32], [16], 64, 1]
#   5                  -1  1     36992  ultralytics.nn.modules.conv.Conv                  [64, 64, 3, 2]
#   6                  -1  1     32880  ultralytics.nn.modules.block_pruned.C3k2Pruned    [64, 64, [21, 43], [32], [16], [32], [[16, 16]], [[32, 32]], [2], 64, 1, 2, True]
#   7                  -1  1     73984  ultralytics.nn.modules.conv.Conv                  [64, 128, 3, 2]
#   8                  -1  1    130112  ultralytics.nn.modules.block_pruned.C3k2Pruned    [128, 128, [44, 84], [64], [32], [64], [[32, 32]], [[64, 64]], [2], 128, 1, 2, True]
#   9                  -1  1     41344  ultralytics.nn.modules.block_pruned.SPPFPruned    [128, 64, 128, 5, 3, True]
#  10                  -1  1    183936  ultralytics.nn.modules.block_pruned.C2PSAPruned   [128, 256, [128, 128], 128, 1, 0.5]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample              [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat                [1]
#  13                  -1  1     40736  ultralytics.nn.modules.block_pruned.C3k2Pruned    [192, 64, [28, 36], [32], [16], [32], [[16, 16]], [[32, 32]], [2], 64, 1, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample              [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat                [1]
#  16                  -1  1     16608  ultralytics.nn.modules.block_pruned.C3k2Pruned    [128, 32, [4, 28], [16], [16], [16], [[16, 16]], [[16, 16]], [2], 32, 1, 2, True]
#  17                  -1  1      9280  ultralytics.nn.modules.conv.Conv                  [32, 32, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat                [1]
#  19                  -1  1     34304  ultralytics.nn.modules.block_pruned.C3k2Pruned    [96, 64, [34, 30], [32], [16], [32], [[16, 16]], [[32, 32]], [2], 64, 1, 2, True]
#  20                  -1  1     36992  ultralytics.nn.modules.conv.Conv                  [64, 64, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat                [1]
#  22                  -1  1    290752  ultralytics.nn.modules.block_pruned.C3k2PrunedAttn[192, 256, [128, 128], 1, [32], 128, True]
#  23        [16, 19, 22]  1    109396  ultralytics.nn.modules.head_pruned.DetectPruned   [[16, 16, 16], [16, 16, 16], [32, 64, 128], [32, 32, 32], [32, 32, 32], [32, 32, 32], [16, 16, 16], [16, 16, 16], [32, 64, 128], [32, 32, 32], [32, 32, 32], [32, 32, 32], 10, 1, (32, 64, 128)]
# Model summary: 258 layers, 1,071,684 parameters, 1,071,684 gradients, 2.6 GFLOPs
#
# Transferred 708/708 items from pretrained weights
# DDP: debug command /usr/bin/python3 -m torch.distributed.run --nproc_per_node 2 --master_port 55799 /root/.config/Ultralytics/DDP/_temp_ft376tjo140107768297280.py
# Ultralytics 8.4.14 🚀 Python-3.12.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 14912MiB)
#                                                       CUDA:1 (Tesla T4, 14912MiB)
# Finetune mode: building DetectionModelPruned with maskbndict
# Transferred 708/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2516.9±1023.2 MB/s, size: 206.8 KB)
# train: Scanning /kaggle/working/datasets/VisDrone/labels/train.cache... 6471 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6471/6471 1.1Git/s 0.0s
# train: /kaggle/working/datasets/VisDrone/images/train/0000137_02220_d_0000163.jpg: 1 duplicate labels removed
# train: /kaggle/working/datasets/VisDrone/images/train/0000140_00118_d_0000002.jpg: 1 duplicate labels removed
# train: /kaggle/working/datasets/VisDrone/images/train/9999945_00000_d_0000114.jpg: 1 duplicate labels removed
# train: /kaggle/working/datasets/VisDrone/images/train/9999987_00000_d_0000049.jpg: 1 duplicate labels removed
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1355.0±772.4 MB/s, size: 136.5 KB)
# val: Scanning /kaggle/working/datasets/VisDrone/labels/val.cache... 548 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 548/548 16.4Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.01, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to /kaggle/working/yolo/runs/vd_oursn/labels.jpg...
# [KD] Channel masks: 4 layers have mismatch
# [KD] ENABLED: method=cwd, teacher=/kaggle/working/yolo/runs/vd_yolo26n/weights/best.pt, lambda=0.5
# [KD] layers=['model.13', 'model.16', 'model.19', 'model.22'], temp=fixed
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/yolo/runs/vd_oursn
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100       3.3G      3.074      4.338   0.005524        360        640: 100% ━━━━━━━━━━━━ 405/405 1.8it/s 3:42
# [CWD] Epoch 0: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.3s
#                    all        548      38759      0.314       0.13      0.084     0.0401
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      3.31G      2.585      2.255   0.003813        351        640: 100% ━━━━━━━━━━━━ 405/405 2.4it/s 2:51
# [CWD] Epoch 1: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.7it/s 3.1s
#                    all        548      38759      0.384      0.172      0.134     0.0706
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      3.31G      2.506      2.109   0.003568        278        640: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:34
# [CWD] Epoch 2: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.6it/s 3.2s
#                    all        548      38759      0.266      0.184      0.159     0.0838
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      3.31G       2.46      2.025   0.003459        384        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:26
# [CWD] Epoch 3: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.8it/s 3.1s
#                    all        548      38759      0.231      0.194      0.171     0.0887
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      3.31G      2.404      1.962   0.003408        406        640: 100% ━━━━━━━━━━━━ 405/405 2.8it/s 2:26
# [CWD] Epoch 4: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.8it/s 3.1s
#                    all        548      38759      0.273      0.211      0.185     0.0989
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      3.31G      2.407      1.943   0.003336        371        640: 100% ━━━━━━━━━━━━ 405/405 2.5it/s 2:39
# [CWD] Epoch 5: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 6.0it/s 3.0s
#                    all        548      38759      0.276      0.223      0.193      0.103
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      3.31G      2.378      1.889   0.003275        349        640: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:37
# [CWD] Epoch 6: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.6s
#                    all        548      38759      0.292       0.22      0.204       0.11
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      3.31G      2.356       1.87   0.003247        432        640: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:38
# [CWD] Epoch 7: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.7it/s 3.2s
#                    all        548      38759      0.303      0.235      0.211      0.112
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      4.15G      2.353      1.858   0.003234        392        640: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:39
# [CWD] Epoch 8: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.1s
#                    all        548      38759      0.298      0.239      0.215      0.114
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      4.15G      2.344       1.84   0.003199        189        640: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:39
# [CWD] Epoch 9: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.7it/s 3.2s
#                    all        548      38759      0.302      0.243      0.222      0.118
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      4.15G       2.34      1.832   0.003181        280        640: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:39
# [CWD] Epoch 10: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.7it/s 3.1s
#                    all        548      38759      0.306      0.244       0.22      0.118
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      4.15G      2.336      1.816    0.00318        192        640: 100% ━━━━━━━━━━━━ 405/405 2.5it/s 2:40
# [CWD] Epoch 11: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.8it/s 3.1s
#                    all        548      38759       0.31      0.248      0.224      0.119
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      4.15G      2.333      1.805   0.003157        208        640: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:39
# [CWD] Epoch 12: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.0s
#                    all        548      38759      0.315      0.247      0.224      0.118
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      4.15G      2.314      1.794   0.003158        111        640: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:36
# [CWD] Epoch 13: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.1s
#                    all        548      38759      0.328      0.245      0.226      0.121
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      4.15G      2.311      1.771   0.003129        256        640: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:37
# [CWD] Epoch 14: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.1s
#                    all        548      38759      0.317      0.243      0.224       0.12
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      4.15G      2.307      1.775   0.003124        247        640: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:38
# [CWD] Epoch 15: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.1s
#                    all        548      38759       0.32      0.253      0.237      0.128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      4.15G        2.3      1.767   0.003102        312        640: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:37
# [CWD] Epoch 16: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.6it/s 3.2s
#                    all        548      38759      0.333      0.254      0.237      0.128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      4.15G      2.278      1.751   0.003101        345        640: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:37
# [CWD] Epoch 17: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.4it/s 3.4s
#                    all        548      38759      0.317      0.254      0.232      0.122
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      4.15G      2.299      1.747   0.003089        260        640: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:39
# [CWD] Epoch 18: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.8it/s 3.1s
#                    all        548      38759      0.332       0.27      0.243       0.13
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      4.15G      2.298      1.744   0.003093        220        640: 100% ━━━━━━━━━━━━ 405/405 2.5it/s 2:39
# [CWD] Epoch 19: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.1s
#                    all        548      38759      0.338      0.263      0.244      0.132
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      4
tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                    all        548      38759       0.38      0.295      0.288      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      4.16G      2.145      1.534   0.002737        336        640: 100% ━━━━━━━━━━━━ 405/405 2.5it/s 2:41
# [CWD] Epoch 88: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.0s
#                    all        548      38759      0.374      0.299      0.288      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      4.16G      2.155      1.546   0.002751        279        640: 100% ━━━━━━━━━━━━ 405/405 2.5it/s 2:41
# [CWD] Epoch 89: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.7it/s 3.2s
#                    all        548      38759      0.374        0.3      0.289      0.162
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      4.16G      2.069      1.491   0.002806        281        640: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:35
# [CWD] Epoch 90: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.8it/s 3.1s
#                    all        548      38759       0.38      0.297      0.287      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      4.16G      2.051      1.466   0.002793        273        640: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:33
# [CWD] Epoch 91: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.1it/s 3.5s
#                    all        548      38759      0.377      0.296      0.288      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      4.16G      2.063      1.478   0.002786        191        640: 100% ━━━━━━━━━━━━ 405/405 2.7it/s 2:33
# [CWD] Epoch 92: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 6.1it/s 2.9s
#                    all        548      38759       0.38      0.296      0.288      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      4.16G      2.056      1.467    0.00278        171        640: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:33
# [CWD] Epoch 93: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.8it/s 3.1s
#                    all        548      38759       0.38      0.295      0.288      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      4.16G      2.057      1.475   0.002799         76        640: 100% ━━━━━━━━━━━━ 405/405 2.7it/s 2:31
# [CWD] Epoch 94: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.9it/s 3.7s
#                    all        548      38759      0.381      0.295      0.288      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      4.16G      2.023      1.451   0.002792        204        640: 100% ━━━━━━━━━━━━ 405/405 2.7it/s 2:31
# [CWD] Epoch 95: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.1s
#                    all        548      38759      0.386      0.292      0.287      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      4.16G      2.045      1.459    0.00278        129        640: 100% ━━━━━━━━━━━━ 405/405 2.7it/s 2:30
# [CWD] Epoch 96: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.0s
#                    all        548      38759      0.381      0.298      0.288      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      4.16G      2.047      1.465   0.002774        175        640: 100% ━━━━━━━━━━━━ 405/405 2.7it/s 2:32
# [CWD] Epoch 97: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.0s
#                    all        548      38759      0.383      0.297      0.289      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      4.16G      2.033      1.456   0.002786        161        640: 100% ━━━━━━━━━━━━ 405/405 2.6it/s 2:33
# [CWD] Epoch 98: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.0s
#                    all        548      38759      0.384      0.296      0.289      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      4.16G      2.039      1.456   0.002752        142        640: 100% ━━━━━━━━━━━━ 405/405 2.7it/s 2:33
# [CWD] Epoch 99: tau=9.00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.9it/s 3.1s
#                    all        548      38759      0.381        0.3       0.29      0.163
#
# 100 epochs completed in 4.509 hours.
# Optimizer stripped from /kaggle/working/yolo/runs/vd_oursn/weights/last.pt, 2.6MB
# Optimizer stripped from /kaggle/working/yolo/runs/vd_oursn/weights/best.pt, 2.6MB
#
# Validating /kaggle/working/yolo/runs/vd_oursn/weights/best.pt...
# Model summary (fused): 144 layers, 1,065,244 parameters, 0 gradients, 2.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 3.4it/s 5.2s
#                    all        548      38759      0.385      0.298       0.29      0.163
#             pedestrian        520       8844      0.387      0.342      0.319      0.132
#                 people        482       5125      0.415       0.25      0.259     0.0918
#                bicycle        364       1287        0.2     0.0575     0.0561     0.0211
#                    car        515      14064      0.562      0.737      0.723      0.481
#                    van        421       1975      0.426      0.321      0.322      0.219
#                  truck        266        750      0.375       0.24      0.225      0.146
#               tricycle        337       1045      0.342      0.161      0.169     0.0896
#        awning-tricycle        220        532      0.256      0.107      0.101     0.0633
#                    bus        131        251      0.474      0.371      0.386      0.252
#                  motor        485       4886      0.411      0.393      0.335      0.132
# Speed: 0.1ms preprocess, 2.4ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /kaggle/working/yolo/runs/vd_oursn

# %% [markdown]
# ## 8. Ket qua

# %%
def measure(name):
    best = REPO_DIR / "runs" / name / "weights" / "best.pt"
    if done_epochs(name) < EPOCHS or not best.exists():
        return None
    m = YOLO(str(best))
    r = m.val(data=DATA, imgsz=IMGSZ, batch=BATCH, device=DEVICE.split(",")[0])
    return (sum(p.numel() for p in m.model.parameters()) / 1e6,
            r.box.map50 * 100, r.box.map * 100)

rows = [("YOLO26-" + SIZE.upper(), measure(BASE_NAME)),
        ("Ours-" + SIZE.upper(), measure(OURS_NAME))]

print()
if all(v for _, v in rows):
    print("| Model | Params (M) | AP50 | AP50-95 |")
    print("|---|---:|---:|---:|")
    for label, (par, ap50, ap) in rows:
        print("| {} | {:.2f} | {:.2f} | {:.2f} |".format(label, par, ap50, ap))
    print()
    print("XONG ca hai. Gui lai bang tren.")
else:
    print("baseline:", done_epochs(BASE_NAME), "/", EPOCHS, "epoch")
    print("ours    :", done_epochs(OURS_NAME), "/", EPOCHS, "epoch")
    print()
    print("CHUA XONG - Add Data output lan nay roi Save & Run All lai.")
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 14912MiB)
# YOLO26n summary (fused): 122 layers, 2,376,786 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2864.0±587.9 MB/s, size: 131.3 KB)
# val: Scanning /kaggle/working/datasets/VisDrone/labels/val.cache... 548 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 548/548 191.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 4.7it/s 7.4s
#                    all        548      38759      0.464      0.343      0.348      0.198
#             pedestrian        520       8844      0.484      0.378       0.39      0.169
#                 people        482       5125      0.472      0.278      0.299       0.11
#                bicycle        364       1287       0.25      0.127     0.0979     0.0397
#                    car        515      14064      0.627      0.756       0.76      0.517
#                    van        421       1975       0.47      0.368      0.375      0.255
#                  truck        266        750        0.5      0.308      0.314      0.195
#               tricycle        337       1045      0.398      0.222      0.234      0.124
#        awning-tricycle        220        532      0.316      0.143      0.131     0.0845
#                    bus        131        251      0.635      0.458      0.482      0.316
#                  motor        485       4886      0.491      0.397      0.397      0.165
# Speed: 0.6ms preprocess, 2.7ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /kaggle/working/yolo/runs/detect/val
# Ultralytics 8.4.14 🚀 Python-3.12.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 14912MiB)
# Model summary (fused): 144 layers, 1,065,244 parameters, 0 gradients, 2.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3049.1±642.9 MB/s, size: 159.3 KB)
# val: Scanning /kaggle/working/datasets/VisDrone/labels/val.cache... 548 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 548/548 209.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 4.8it/s 7.2s
#                    all        548      38759      0.381        0.3       0.29      0.163
#             pedestrian        520       8844      0.383      0.344      0.318      0.133
#                 people        482       5125      0.408      0.252      0.258     0.0918
#                bicycle        364       1287      0.195     0.0583     0.0558     0.0212
#                    car        515      14064      0.558      0.738      0.723      0.482
#                    van        421       1975      0.425      0.321      0.322      0.219
#                  truck        266        750      0.369      0.241      0.225      0.145
#               tricycle        337       1045      0.339      0.163      0.168     0.0893
#        awning-tricycle        220        532      0.251      0.107      0.103     0.0637
#                    bus        131        251      0.476      0.376      0.387      0.253
#                  motor        485       4886      0.407      0.396      0.335      0.132
# Speed: 0.6ms preprocess, 2.4ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /kaggle/working/yolo/runs/detect/val2
#
# | Model | Params (M) | AP50 | AP50-95 |
# |---|---:|---:|---:|
# | YOLO26-N | 2.38 | 34.80 | 19.75 |
# | Ours-N | 1.07 | 28.96 | 16.30 |
#
# XONG ca hai. Gui lai bang tren.
